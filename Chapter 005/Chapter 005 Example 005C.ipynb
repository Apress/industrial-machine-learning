# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# # Chapter 05 Example 005C

# %% [markdown]
# ## Part A - Load Libraries

# %%
import tensorflow as tf
import os
import pandas as pd

# %% [markdown]
# ## Part B - Load Dummy Data Set

# %%
mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

labelfile='../../data/fashion01.csv'
labelset = pd.read_csv(labelfile, header=0)

print('Training Data..:', x_train.shape, y_train.shape)
print('Test Data......:',x_test.shape, y_test.shape)
print('Label Data.....:',labelset.shape)
# Out:
# Training Data..: (60000, 28, 28) (60000,)
# Test Data......: (10000, 28, 28) (10000,)
# Label Data.....: (10, 2)

# %% [markdown]
# ## Part C - Built Tensorflow Model

# %%
tfmodel = tf.keras.models.Sequential([
      tf.keras.layers.Flatten(input_shape=(28, 28)),
      tf.keras.layers.Dense(512, 
                            activation=tf.nn.relu,
                            use_bias=True,
                            kernel_initializer='lecun_uniform',
                            bias_initializer='zeros',
                            kernel_regularizer=None,
                            bias_regularizer=None,
                            activity_regularizer=None,
                            kernel_constraint=None,
                            bias_constraint=None
                           ),
      tf.keras.layers.Dropout(rate=0.8,
                              seed=0,
                              name='Fashion-Tensorflow',
                              noise_shape=None),
      tf.keras.layers.Dense(10,
                            activation=tf.nn.softmax,
                            use_bias=True,
                            kernel_initializer='lecun_uniform',
                            bias_initializer='zeros',
                            kernel_regularizer=None,
                            bias_regularizer=None,
                            activity_regularizer=None,
                            kernel_constraint=None,
                            bias_constraint=None
                           )
])
# Out:
# WARNING:tensorflow:From C:\Users\AndreVermeulen\AppData\Local\conda\conda\envs\py36\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\AndreVermeulen\AppData\Local\conda\conda\envs\py36\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
tfmodel.get_config()
# Out:
# {'name': 'sequential',
#  'layers': [{'class_name': 'Flatten',
#    'config': {'name': 'flatten',
#     'trainable': True,
#     'batch_input_shape': (None, 28, 28),
#     'dtype': 'float32',
#     'data_format': 'channels_last'}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 512,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_in',
#       'distribution': 'uniform',
#       'seed': None,
#       'dtype': 'float32'}},
#     'bias_initializer': {'class_name': 'Zeros',
#      'config': {'dtype': 'float32'}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Dropout',
#    'config': {'name': 'Fashion-Tensorflow',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.8,
#     'noise_shape': None,
#     'seed': 0}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 10,
#     'activation': 'softmax',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_in',
#       'distribution': 'uniform',
#       'seed': None,
#       'dtype': 'float32'}},
#     'bias_initializer': {'class_name': 'Zeros',
#      'config': {'dtype': 'float32'}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}}]}

# %% [markdown]
# ## Part D - Compile Tensorflow Model

# %%
tfmodel.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'],
                loss_weights=None,
                sample_weight_mode=None,
                weighted_metrics=None,
                target_tensors=None               
               )

# %% [markdown]
# ## Part E - Train the Model

# %%
r = tfmodel.fit(x_train, 
            y_train, 
            epochs=15,
            batch_size=32,
            callbacks=None,
            validation_split=0.0, 
            validation_data=None, 
            shuffle=True, 
            class_weight=None, 
            sample_weight=None, 
            initial_epoch=0, 
            steps_per_epoch=None, 
            validation_steps=None,
            verbose=1)
# Out:
# Epoch 1/15
# 60000/60000 [==============================] - 49s 812us/sample - loss: 0.7100 - acc: 0.7410
# Epoch 2/15
# 60000/60000 [==============================] - 43s 722us/sample - loss: 0.5732 - acc: 0.7912
# Epoch 3/15
# 60000/60000 [==============================] - 44s 736us/sample - loss: 0.5415 - acc: 0.8023 -
# Epoch 4/15
# 60000/60000 [==============================] - 44s 738us/sample - loss: 0.5259 - acc: 0.8105 - loss: 0.5256 - acc: 0.81
# Epoch 5/15
# 60000/60000 [==============================] - 35s 578us/sample - loss: 0.5112 - acc: 0.8148
# Epoch 6/15
# 60000/60000 [==============================] - 24s 396us/sample - loss: 0.5026 - acc: 0.8149
# Epoch 7/15
# 60000/60000 [==============================] - 23s 377us/sample - loss: 0.4929 - acc: 0.8205
# Epoch 8/15
# 60000/60000 [==============================] - 23s 375us/sample - loss: 0.4890 - acc: 0.8216
# Epoch 9/15
# 60000/60000 [==============================] - 22s 374us/sample - loss: 0.4841 - acc: 0.8246
# Epoch 10/15
# 60000/60000 [==============================] - 22s 372us/sample - loss: 0.4778 - acc: 0.8263
# Epoch 11/15
# 60000/60000 [==============================] - 22s 372us/sample - loss: 0.4717 - acc: 0.8284
# Epoch 12/15
# 60000/60000 [==============================] - 22s 371us/sample - loss: 0.4701 - acc: 0.8306
# Epoch 13/15
# 60000/60000 [==============================] - 22s 371us/sample - loss: 0.4671 - acc: 0.8309
# Epoch 14/15
# 60000/60000 [==============================] - 22s 374us/sample - loss: 0.4593 - acc: 0.8316
# Epoch 15/15
# 60000/60000 [==============================] - 22s 372us/sample - loss: 0.4602 - acc: 0.8316 -

# %%
print(r)
# Out:
# <tensorflow.python.keras.callbacks.History object at 0x00000117D35D21D0>

# %% [markdown]
# ## Part F - Evaluate Model

# %%
e = tfmodel.evaluate(x_test, 
                 y_test, 
                 batch_size=32, 
                 verbose=1, 
                 sample_weight=None, 
                 steps=None)
# Out:
# 10000/10000 [==============================] - 1s 125us/sample - loss: 0.3940 - acc: 0.8620

# %%
print('Error loss: %7.4f %% Accuracy: %7.4f %%' % (e[0]*100,e[1]*100))
# Out:
# Error loss: 39.4028 % Accuracy: 86.2000 %

# %% [markdown]
# ## Part G - Save Model

# %%
imagepath = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 05'])
print(imagepath)
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrialized Machine Learning\book\IML\Results\Chapter 05

# %%
if not os.path.exists(imagepath):
    os.makedirs(imagepath)

# %%
modelname = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 05','Chapter-005-Example-005C-01.hdf5'])
print(modelname)
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrialized Machine Learning\book\IML\Results\Chapter 05\Chapter-005-Example-005C-01.hdf5

# %%
tf.keras.models.save_model(
    tfmodel,
    modelname,
    overwrite=True,
    include_optimizer=True
)

# %% [markdown]
# ## Part H - Load Model

# %%
tfmodel2 = tf.keras.models.load_model(
    modelname,
    custom_objects=None,
    compile=True
)

# %% [markdown]
# ## Part I - Evaluate Loaded Model

# %%
e2 = tfmodel2.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 1s 125us/sample - loss: 0.3940 - acc: 0.8620

# %%
print('Error loss: %7.4f Accuracy: %7.4f' % (e2[0],e2[1]))
# Out:
# Error loss:  0.3940 Accuracy:  0.8620

# %% [markdown]
# ## Part J - Predict with Loaded Model

# %%
y_pred = tfmodel2.predict(x_test, batch_size=32, verbose=1, steps=None)
# Out:
# 10000/10000 [==============================] - 1s 91us/sample

# %% [markdown]
# ## Part K - Display Predict Results

# %%
filetxt= os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 05','Chapter-005-Example-005C-01.txt'])
print(filetxt)
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrialized Machine Learning\book\IML\Results\Chapter 05\Chapter-005-Example-005C-01.txt

# %%
print(labelset)
# Out:
#    Label  Description
# 0      0  T-shirt/top
# 1      1      Trouser
# 2      2     Pullover
# 3      3        Dress
# 4      4         Coat
# 5      5       Sandal
# 6      6        Shirt
# 7      7      Sneaker
# 8      8          Bag
# 9      9   Ankle boot

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
f = open(filetxt,'w')
h=0
m=0
for i in range(x_test.shape[0]):
    line = '------------------'
    line = line + '\n' + str('Test: %06d' % (i))
    t=y_test[i]
    line = line + '\n' + 'Seek....:' + str(t) + str(' ( %s )' % (labelset['Description'].loc[t]))
    for j in range(10):
        if int(round(y_pred[i][j],0)) == 1:
            p=j
            line = line + '\n' + 'Predict.:' + str(j) + str(' ( %s )' % (labelset['Description'].loc[p]))
    if t==p:
        line = line + '\n' + 'Hit!'
        h+=1
    else:
        line = line + '\n' + 'Miss?'
        m+=1
    line = line + '\n' + '------------------'  + '\n'
    print(line)
    f.write(line)
p = (h/(h+m)) * 100
line = 'Hit: %6d Miss: %6d => Score: %7.2f %%' % (h,m,p)
print(line)
f.write(line)
f.close()
# Out:
# ------------------
# Test: 000000
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000001
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000002
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000003
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000004
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000005
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000006
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000007
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000008
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000009
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000010
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000011
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000012
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000013
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000014
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000015
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000016
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000017
# Seek....:4 ( Coat )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000018
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000019
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000020
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000021
# Seek....:5 ( Sandal )
# Predict.:7 ( Sneaker )
# Miss?
# ------------------
#
# ------------------
# Test: 000022
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000023
# Seek....:9 ( Ankle boot )
# Predict.:5 ( Sandal )
# Miss?
# ------------------
#
# ------------------
# Test: 000024
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000025
# Seek....:4 ( Coat )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000026
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000027
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000028
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000029
# Seek....:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 000030
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000031
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000032
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000033
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000034
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000035
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000036
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000037
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000038
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000039
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000040
# Seek....:6 ( Shirt )
# Predict.:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 000041
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000042
# Seek....:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 000043
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000044
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000045
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000046
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000047
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000048
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000049
# Seek....:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000050
# Seek....:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000051
# Seek....:4 ( Coat )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000052
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000053
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000054
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000055
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000056
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000057
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000058
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000059
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000060
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000061
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000062
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000063
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000064
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000065
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000066
# Seek....:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000067
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000068
# Seek....:9 ( Ankle boot )
# Predict.:7 ( Sneaker )
# Miss?
# ------------------
#
# ------------------
# Test: 000069
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000070
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000071
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000072
# Seek....:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000073
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000074
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000075
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000076
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000077
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000078
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000079
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000080
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000081
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000082
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000083
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000084
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000085
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000086
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000087
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000088
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000089
# Seek....:6 ( Shirt )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000090
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000091
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000092
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000093
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000094
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000095
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000096
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000097
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000098
# Seek....:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000099
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000100
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000101
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000102
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000103
# Seek....:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000104
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000105
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000106
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000107
# Seek....:9 ( Ankle boot )
# Predict.:7 ( Sneaker )
# Miss?
# ------------------
#
# ------------------
# Test: 000108
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000109
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000110
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000111
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000112
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000113
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000114
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000115
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000116
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000117
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000118
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000119
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000120
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000121
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000122
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000123
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000124
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000125
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000126
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000127
# Seek....:4 ( Coat )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000128
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000129
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000130
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000131
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000132
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000133
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000134
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000135
# Seek....:6 ( Shirt )
# Predict.:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000136
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000137
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000138
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000139
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000140
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000141
# Seek....:0 ( T-shirt/top )
# Predict.:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000142
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000143
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000144
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000145
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000146
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000147
# Seek....:6 ( Shirt )
# Predict.:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 000148
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000149
# Seek....:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000150
# Seek....:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000151
# Seek....:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000152
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000153
# Seek....:4 ( Coat )
# Predict.:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 000154
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000155
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000156
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000157
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000158
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000159
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000160
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000161
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000162
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000163
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000164
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000165
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000166
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000167
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000168
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000169
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000170
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000171
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000172
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000173
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000174
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000175
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000176
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000177
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000178
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000179
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000180
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000181
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000182
# Seek....:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 000183
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000184
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000185
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000186
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000187
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000188
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000189
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000190
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000191
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000192
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000193
# Seek....:6 ( Shirt )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000194
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000195
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000196
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000197
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000198
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000199
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000200
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000201
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000202
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000203
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000204
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000205
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000206
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000207
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000208
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000209
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000210
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000211
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000212
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000213
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000214
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000215
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000216
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000217
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000218
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000219
# Seek....:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000220
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000221
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000222
# Seek....:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000223
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000224
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000225
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000226
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000227
# Seek....:2 ( Pullover )
# Predict.:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000228
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000229
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000230
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000231
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000232
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000233
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000234
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000235
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000236
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000237
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000238
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000239
# Seek....:4 ( Coat )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000240
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000241
# Seek....:6 ( Shirt )
# Predict.:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000242
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000243
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000244
# Seek....:6 ( Shirt )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000245
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000246
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000247
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000248
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000249
# Seek....:2 ( Pullover )
# Predict.:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000250
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000251
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000252
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000253
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000254
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000255
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000256
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000257
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000258
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000259
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000260
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000261
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000262
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000263
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000264
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000265
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000266
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000267
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000268
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000269
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000270
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000271
# Seek....:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 000272
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000273
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000274
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000275
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000276
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000277
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000278
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000279
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000280
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000281
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000282
# Seek....:6 ( Shirt )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000283
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000284
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000285
# Seek....:6 ( Shirt )
# Predict.:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000286
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000287
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000288
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000289
# Seek....:4 ( Coat )
# Predict.:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 000290
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000291
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000292
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000293
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000294
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000295
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000296
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000297
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000298
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000299
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000300
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000301
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000302
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000303
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000304
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000305
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000306
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000307
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000308
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000309
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000310
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000311
# Seek....:3 ( Dress )
# Predict.:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000312
# Seek....:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000313
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000314
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000315
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000316
# Seek....:9 ( Ankle boot )
# Predict.:7 ( Sneaker )
# Miss?
# ------------------
#
# ------------------
# Test: 000317
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000318
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000319
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000320
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000321
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000322
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000323
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000324
# Seek....:4 ( Coat )
# Predict.:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000325
# Seek....:6 ( Shirt )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000326
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000327
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000328
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000329
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000330
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000331
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000332
# Seek....:0 ( T-shirt/top )
# Predict.:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000333
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000334
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000335
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000336
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000337
# Seek....:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000338
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000339
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000340
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000341
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000342
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000343
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000344
# Seek....:6 ( Shirt )
# Predict.:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 000345
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000346
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000347
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000348
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000349
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000350
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000351
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000352
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000353
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000354
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000355
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000356
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000357
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000358
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000359
# Seek....:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 000360
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000361
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000362
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000363
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000364
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000365
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000366
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000367
# Seek....:2 ( Pullover )
# Predict.:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000368
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000369
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000370
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000371
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000372
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000373
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000374
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000375
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000376
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000377
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000378
# Seek....:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000379
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000380
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000381
# Seek....:0 ( T-shirt/top )
# Predict.:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000382
# Seek....:2 ( Pullover )
# Predict.:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 000383
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000384
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000385
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000386
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000387
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000388
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000389
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000390
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000391
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000392
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000393
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000394
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000395
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000396
# Seek....:4 ( Coat )
# Predict.:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000397
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000398
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000399
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000400
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000401
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000402
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000403
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000404
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000405
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
# ------------------
# Test: 000406
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000407
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000408
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000409
# Seek....:1 ( Trouser )
# Predict.:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 000410
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000411
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000412
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 000413
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000414
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000415
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000416
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000417
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000418
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000419
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000420
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000421
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000422
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000423
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000424
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000425
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000426
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000427
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000428
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000429
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000430
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000431
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000432
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000433
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000434
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000435
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000436
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000437
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000438
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000439
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000440
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000441
# Seek....:9 ( Ankle boot )
# Predict.:7 ( Sneaker )
# Miss?
# ------------------
#
# ------------------
# Test: 000442
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000443
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000444
# Seek....:6 ( Shirt )
# Predict.:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000445
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000446
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000447
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000448
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000449
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 000450
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000451
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000452
# Seek....:0 ( T-shirt/top )
# Predict.:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 000453
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 000454
# Seek....:0 ( T-shirt/top )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 000455
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000456
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000457
# Seek....:2 ( Pullover )
# Predict.:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 000458
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000459
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 000460
# Seek....:3 ( Dress )
# Predict.:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 000461
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000462
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000463
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000464
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000465
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000466
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 000467
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000468
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 000469
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 000470
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 000471
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 000472
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 000473
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# ...
# Test: 009842
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009843
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009844
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009845
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009846
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009847
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009848
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009849
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009850
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009851
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009852
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 009853
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009854
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009855
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 009856
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009857
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009858
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009859
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 009860
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009861
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009862
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009863
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009864
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009865
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009866
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009867
# Seek....:0 ( T-shirt/top )
# Predict.:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 009868
# Seek....:6 ( Shirt )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 009869
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009870
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009871
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009872
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009873
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009874
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009875
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 009876
# Seek....:5 ( Sandal )
# Predict.:9 ( Ankle boot )
# Miss?
# ------------------
#
# ------------------
# Test: 009877
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 009878
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009879
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009880
# Seek....:0 ( T-shirt/top )
# Predict.:1 ( Trouser )
# Miss?
# ------------------
#
# ------------------
# Test: 009881
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 009882
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009883
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009884
# Seek....:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 009885
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009886
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009887
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 009888
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009889
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009890
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009891
# Seek....:1 ( Trouser )
# Miss?
# ------------------
#
# ------------------
# Test: 009892
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009893
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 009894
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009895
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009896
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009897
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009898
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009899
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009900
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 009901
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009902
# Seek....:0 ( T-shirt/top )
# Predict.:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 009903
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009904
# Seek....:6 ( Shirt )
# Predict.:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 009905
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009906
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009907
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009908
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009909
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009910
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009911
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009912
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009913
# Seek....:4 ( Coat )
# Predict.:3 ( Dress )
# Miss?
# ------------------
#
# ------------------
# Test: 009914
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 009915
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009916
# Seek....:1 ( Trouser )
# Miss?
# ------------------
#
# ------------------
# Test: 009917
# Seek....:7 ( Sneaker )
# Predict.:9 ( Ankle boot )
# Miss?
# ------------------
#
# ------------------
# Test: 009918
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009919
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009920
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009921
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009922
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009923
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009924
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009925
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009926
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009927
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009928
# Seek....:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 009929
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009930
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 009931
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009932
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009933
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009934
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009935
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009936
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009937
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009938
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009939
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009940
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009941
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009942
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009943
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009944
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009945
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009946
# Seek....:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 009947
# Seek....:6 ( Shirt )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 009948
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009949
# Seek....:5 ( Sandal )
# Predict.:7 ( Sneaker )
# Miss?
# ------------------
#
# ------------------
# Test: 009950
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009951
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009952
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009953
# Seek....:6 ( Shirt )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 009954
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009955
# Seek....:6 ( Shirt )
# Predict.:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 009956
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009957
# Seek....:6 ( Shirt )
# Predict.:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 009958
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009959
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009960
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009961
# Seek....:6 ( Shirt )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 009962
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 009963
# Seek....:4 ( Coat )
# Miss?
# ------------------
#
# ------------------
# Test: 009964
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009965
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009966
# Seek....:4 ( Coat )
# Predict.:4 ( Coat )
# Hit!
# ------------------
#
# ------------------
# Test: 009967
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009968
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009969
# Seek....:8 ( Bag )
# Miss?
# ------------------
#
# ------------------
# Test: 009970
# Seek....:2 ( Pullover )
# Predict.:2 ( Pullover )
# Hit!
# ------------------
#
# ------------------
# Test: 009971
# Seek....:6 ( Shirt )
# Predict.:6 ( Shirt )
# Hit!
# ------------------
#
# ------------------
# Test: 009972
# Seek....:2 ( Pullover )
# Predict.:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 009973
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009974
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009975
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009976
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009977
# Seek....:6 ( Shirt )
# Predict.:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 009978
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009979
# Seek....:6 ( Shirt )
# Predict.:0 ( T-shirt/top )
# Miss?
# ------------------
#
# ------------------
# Test: 009980
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009981
# Seek....:0 ( T-shirt/top )
# Predict.:0 ( T-shirt/top )
# Hit!
# ------------------
#
# ------------------
# Test: 009982
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009983
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009984
# Seek....:3 ( Dress )
# Predict.:3 ( Dress )
# Hit!
# ------------------
#
# ------------------
# Test: 009985
# Seek....:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 009986
# Seek....:7 ( Sneaker )
# Predict.:7 ( Sneaker )
# Hit!
# ------------------
#
# ------------------
# Test: 009987
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009988
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009989
# Seek....:4 ( Coat )
# Predict.:2 ( Pullover )
# Miss?
# ------------------
#
# ------------------
# Test: 009990
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# ------------------
# Test: 009991
# Seek....:6 ( Shirt )
# Miss?
# ------------------
#
# ------------------
# Test: 009992
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009993
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009994
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009995
# Seek....:9 ( Ankle boot )
# Predict.:9 ( Ankle boot )
# Hit!
# ------------------
#
# ------------------
# Test: 009996
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009997
# Seek....:8 ( Bag )
# Predict.:8 ( Bag )
# Hit!
# ------------------
#
# ------------------
# Test: 009998
# Seek....:1 ( Trouser )
# Predict.:1 ( Trouser )
# Hit!
# ------------------
#
# ------------------
# Test: 009999
# Seek....:5 ( Sandal )
# Predict.:5 ( Sandal )
# Hit!
# ------------------
#
# Hit:   8349 Miss:   1651 => Score:   83.49 %

# %% [markdown]
# ## Done

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
# Out:
# Done! 2019-04-14 12:04:37.282356
