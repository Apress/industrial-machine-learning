# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# # Chapter 004 Example 019

# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor

# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(200 * rng.rand(100, 1) - 100, axis=0)
y = np.array([np.pi * np.sin(X).ravel(), np.pi * np.cos(X).ravel()]).T
y[::5, :] += (0.5 - rng.rand(20, 2))

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_3 = DecisionTreeRegressor(max_depth=8)
regr_4 = DecisionTreeRegressor(max_depth=None)

regr_1.fit(X, y)
regr_2.fit(X, y)
regr_3.fit(X, y)
regr_4.fit(X, y)

# Predict
X_test = np.arange(-100.0, 100.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)
y_3 = regr_3.predict(X_test)
y_4 = regr_4.predict(X_test)

# Plot the results
fig=plt.figure(figsize=(12, 12))
s = 55
s2 = 200
plt.scatter(y[:, 0], y[:, 1], c="navy", s=s2, edgecolor="black", label="data", marker='o')
plt.scatter(y_1[:, 0], y_1[:, 1], c="cornflowerblue", s=s, edgecolor="black", label="max_depth=2", marker='p')
plt.scatter(y_2[:, 0], y_2[:, 1], c="red", s=s, edgecolor="black", label="max_depth=5", marker='^')
plt.scatter(y_3[:, 0], y_3[:, 1], c="orange", s=s, edgecolor="black", label="max_depth=8", marker='d')
plt.xlim([-6, 6])
plt.ylim([-6, 6])
plt.xlabel("target 1")
plt.ylabel("target 2")
plt.title("Multi-output Decision Tree Regression")
plt.legend(loc="best")
plt.show()

# %%
print('Outputs Fit 1:', regr_1.n_outputs_)
print('Outputs Fit 2:', regr_2.n_outputs_)
print('Outputs Fit 3:', regr_3.n_outputs_)
# Out:
# Outputs Fit 1: 2
# Outputs Fit 2: 2
# Outputs Fit 3: 2

# %%
print('Score max_depth=2   : %7.4f with %4d nodes or %8.4f %% of tree' % (regr_1.score(X, y), regr_1.tree_.node_count, (regr_1.tree_.node_count*100/regr_4.tree_.node_count)))
print('Score max_depth=5   : %7.4f with %4d nodes or %8.4f %% of tree' % (regr_2.score(X, y), regr_2.tree_.node_count, (regr_2.tree_.node_count*100/regr_4.tree_.node_count)))
print('Score max_depth=8   : %7.4f with %4d nodes or %8.4f %% of tree' % (regr_3.score(X, y), regr_3.tree_.node_count, (regr_3.tree_.node_count*100/regr_4.tree_.node_count)))
print('Score max_depth=None: %7.4f with %4d nodes or %8.4f %% of tree' % (regr_4.score(X, y), regr_4.tree_.node_count, (regr_4.tree_.node_count*100/regr_4.tree_.node_count)))
# Out:
# Score max_depth=2   :  0.1081 with    7 nodes or   3.5176 % of tree
# Score max_depth=5   :  0.5295 with   53 nodes or  26.6332 % of tree
# Score max_depth=8   :  0.8797 with  161 nodes or  80.9045 % of tree
# Score max_depth=None:  1.0000 with  199 nodes or 100.0000 % of tree

# %%
imagepath = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 04'])
print(imagepath)
if not os.path.exists(imagepath):
    os.makedirs(imagepath)
imagename = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 04','Chapter-004-Example-019-01.jpg'])
fig.savefig(imagename, bbox_inches='tight')
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrialized Machine Learning\book\IML\Results\Chapter 04

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
# Out:
# Done! 2019-04-09 11:17:11.519137
