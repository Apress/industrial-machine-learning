# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# # Chapter 004 Example 005A

# %% [markdown]
#  Using Least-angle regression (LARS) is an algorithm for fitting linear regression models to high-dimensional data sets.

# %% [markdown]
# ## Part A - Load libraries

# %%
from sklearn import linear_model

import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Part B - Load Data for 4 Features

# %%
fileName = '../../Data/Sickness04.csv'
fileFullName = os.path.abspath(fileName)
print(fileFullName)
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrialized Machine Learning\book\IML\Data\Sickness04.csv

# %%
sickdf= pd.read_csv(fileFullName,header=0)
print(sickdf.shape)
# Out:
# (442, 11)

# %%
sickness = np.array(sickdf)
sickness_data = np.array(sickdf[['F01','F02','F03','F04']].copy(deep=True))
sickness_target = np.array(sickdf[['T'][0]].copy(deep=True))
X = sickness_data
y = sickness_target

# %% [markdown]
# ## Part B - Compute the LARS algorithm

# %%
print("Computing regularization path using the LARS algorithm:")
alphas, _, coefs = linear_model.lars_path(X, y, method='lasso', verbose=True)

xx = np.sum(np.abs(coefs.T), axis=1)
xx /= xx[-1]

fig = plt.figure(figsize=(12, 9))
plt.plot(xx, coefs.T)
ymin, ymax = plt.ylim()
plt.vlines(xx, ymin, ymax, linestyle='dashed')
plt.xlabel('|coef| / max|coef|')
plt.ylabel('Coefficients')
plt.title('LASSO Path for Sickness 4 Features')
plt.axis('tight')
plt.show()
# Out:
# Computing regularization path using the LARS algorithm:
# .

# %%
imagepath = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 04'])
print(imagepath)
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrialized Machine Learning\book\IML\Results\Chapter 04

# %%
if not os.path.exists(imagepath):
    os.makedirs(imagepath)

# %%
imagename = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 04','Chapter-004-Example-005A-01.jpg'])
fig.savefig(imagename, bbox_inches='tight')

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
# Out:
# Done! 2019-04-06 14:09:56.724749
