# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# ## Chapter-009-014-Recommender-Network-03

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
import os

# %%
n = ['A','B','C','D','E','F']

# %%
G=nx.Graph()
G.add_nodes_from(n)

# %%
print("Nodes of graph: ")
print(G.nodes())
# Out:
# Nodes of graph:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
G.add_edge('A','B',weight=25)
G.add_edge('A','C',weight=150)
G.add_edge('A','D',weight=25)
G.add_edge('A','E',weight=22)


G.add_edge('B','C',weight=100)
G.add_edge('B','D',weight=15)

G.add_edge('C','E',weight=333)
G.add_edge('C','F',weight=280)

G.add_edge('D','F',weight=150)

G.add_edge('E','F',weight=60)
G.add_edge('E','G',weight=180)

G.add_edge('F','G',weight=390)

# %%
print("Nodes of graph: ")
print(G.nodes())
print("Edges of graph: ")
print(G.edges())
# Out:
# Nodes of graph:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']
# Edges of graph:
# [('A', 'B'), ('A', 'C'), ('A', 'D'), ('A', 'E'), ('B', 'C'), ('B', 'D'), ('C', 'E'), ('C', 'F'), ('D', 'F'), ('E', 'F'), ('E', 'G'), ('F', 'G')]

# %%
pos=nx.circular_layout(G, dim=2, scale=2)

fig1=plt.figure(figsize=(10, 10))
nx.draw(G, pos=pos, node_size=800, node_shape='D')
labels=nx.draw_networkx_labels(G,pos=pos)
edge_labels=nx.draw_networkx_edge_labels(G,pos=pos)
plt.draw()
# Out:
# C:\Users\AndreVermeulen\AppData\Local\conda\conda\envs\py36\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
imagepath = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 09'])
print(imagepath)

if not os.path.exists(imagepath):
    os.makedirs(imagepath)
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrialized Machine Learning\book\IML\Results\Chapter 09

# %%
imagename = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 09','Chapter-009-014-Recommender-Network-03-01.jpg'])
fig1.savefig(imagename, bbox_inches='tight')

# %%
print(nx.shortest_path(G,source='A',target='F', weight='weight'))
# Out:
# ['A', 'E', 'F']

# %%
print(nx.shortest_path_length(G,source='A',target='F', weight='weight'))
# Out:
# 82

# %%
print(nx.shortest_path(G,source='A',target='G', weight='weight'))
# Out:
# ['A', 'E', 'G']

# %%
print(nx.shortest_path_length(G,source='A',target='G', weight='weight'))
# Out:
# 202

# %%
for c in range(4):
    print('Cutoff:', c)
    print('=================')
    p = nx.single_source_shortest_path_length(G,source='A', cutoff=c)    
    for key, value in p.items():
        print(key, ' => ', value)
    print('=================')
# Out:
# Cutoff: 0
# =================
# A  =>  0
# =================
# Cutoff: 1
# =================
# A  =>  0
# B  =>  1
# C  =>  1
# D  =>  1
# E  =>  1
# =================
# Cutoff: 2
# =================
# A  =>  0
# B  =>  1
# C  =>  1
# D  =>  1
# E  =>  1
# F  =>  2
# G  =>  2
# =================
# Cutoff: 3
# =================
# A  =>  0
# B  =>  1
# C  =>  1
# D  =>  1
# E  =>  1
# F  =>  2
# G  =>  2
# =================

# %% [markdown]
# ## Done

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
# Out:
# Done! 2019-04-24 21:54:40.142270
