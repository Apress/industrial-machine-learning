# %% [markdown]
# # 08-05-Utility-Data-Profiler-04-Location

# %%
pfilename='08-05-Utility-Data-Profiler-04-Location'
wwwfile='./100-Data-Profiles/' + pfilename + '.html'
fileDataName='08-02-Retrieve-Location.csv.gz'

# %%
#!pip install pandas-profiling

# %%
#conda install pandas-profiling

# %%
import os
import numpy as np
import pandas as pd
import pandas_profiling as pdp

# %%
dirDataName = '../../../../Chapter 08/990-DL/100-Raw-Zone/'
pathRealDataName=os.path.realpath(dirDataName)
print(pathRealDataName)
# Out:
# C:\Users\andre.vermeulen\Documents\My Book\Code\Chapter 08\990-DL\100-Raw-Zone\

# %%
fileFullDataName= os.path.join(pathRealDataName, fileDataName)
print(fileFullDataName)
# Out:
# C:\Users\andre.vermeulen\Documents\My Book\Code\Chapter 08\990-DL\100-Raw-Zone\08-02-Retrieve-Location.csv.gz

# %%
locationFullDF= pd.read_csv(fileFullDataName, encoding='utf-8', compression='gzip')
print(locationFullDF.shape)
# Out:
# (1762397, 4)

# %%
print(locationFullDF.columns)
# Out:
# Index(['id', 'postcode', 'latitude', 'longitude'], dtype='object')

# %%
print(locationFullDF.describe())
# Out:
#                  id      latitude     longitude
# count  1.762397e+06  1.762315e+06  1.762315e+06
# mean   9.437387e+05  5.308300e+01 -1.722698e+00
# std    5.721944e+05  4.225250e+00  1.656035e+00
# min    1.000000e+00  4.918194e+01 -8.163139e+00
# 25%    4.650860e+05  5.150552e+01 -2.723455e+00
# 50%    9.275360e+05  5.247064e+01 -1.583258e+00
# 75%    1.388938e+06  5.368176e+01 -3.544713e-01
# max    2.622341e+06  1.000000e+02  1.760443e+00

# %%
locationFullDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1762397 entries, 0 to 1762396
# Data columns (total 4 columns):
# id           int64
# postcode     object
# latitude     float64
# longitude    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 53.8+ MB

# %%
profile = pdp.ProfileReport(locationFullDF)

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
rejected_variables = profile.get_rejected_variables(threshold=0.9)

# %%
print(rejected_variables)
# Out:
# []

# %%
profile.to_file(outputfile=wwwfile)

# %%
import webbrowser
import os

# %%
wwwRealfile=os.path.realpath(wwwfile)
print(wwwRealfile)
# Out:
# C:\Users\andre.vermeulen\Documents\My Book\Code\Chapter 08\000-RIF\400-Utility-Layer\200-Data-Utilities\100-Data-Profiles\08-05-Utility-Data-Profiler-04-Location.html

# %%
webbrowser.open_new_tab(wwwRealfile)
# Out:
# True
