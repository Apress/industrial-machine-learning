# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# # Chapter-007-009B-Keras-01

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import os
# fix random seed for reproducibility
np.random.seed(7)

# %%
# load pima indians dataset
data_dir = os.path.abspath(os.path.join("..","..", "data"))
print(data_dir)
data_file = os.path.join(data_dir, "Sickness13.csv")
print(data_file)
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrial Machine Learning\book\GitHub\Upload\industrial-machine-learning\data
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrial Machine Learning\book\GitHub\Upload\industrial-machine-learning\data\Sickness13.csv

# %%
rawdata = np.loadtxt(data_file, delimiter=",")
print('Raw Data Set:', rawdata.shape)
dataset = rawdata[:]
print('Data Set:', dataset.shape)
# Out:
# Raw Data Set: (768, 9)
# Data Set: (768, 9)

# %%
# split into input (X) and output (Y) variables
X = np.array(dataset[:,0:8], dtype=np.int32)
Y = np.array(dataset[:,8], dtype=np.int32)
print('X:', X.shape)
print('Y:', Y.shape)
# Out:
# X: (768, 8)
# Y: (768,)

# %%
# create model
model = Sequential()

model.add(Dense(12, 
                input_dim=8, 
                activation='relu'
               )
         )

model.add(Dense(8, 
                activation='softmax'
               )
         )

model.add(Dense(1, 
                activation='sigmoid'
               )
         )
# Out:
# WARNING:tensorflow:From C:\Users\AndreVermeulen\.conda\envs\andre\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# Compile model
model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy']
             )
# Out:
# WARNING:tensorflow:From C:\Users\AndreVermeulen\.conda\envs\andre\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Fit the model
model.fit(X, 
          Y, 
          epochs=25, 
          batch_size=10,
          steps_per_epoch=250, 
          shuffle=True,
          workers=64,
          use_multiprocessing=True, 
          verbose=True
         )
# Out:
# Epoch 1/25
# 250/250 [==============================] - 20s 80ms/step - loss: 0.6319 - acc: 0.6507
# Epoch 2/25
# 250/250 [==============================] - 18s 73ms/step - loss: 0.6152 - acc: 0.6678
# Epoch 3/25
# 250/250 [==============================] - 18s 73ms/step - loss: 0.6043 - acc: 0.6956
# Epoch 4/25
# 250/250 [==============================] - 18s 73ms/step - loss: 0.5963 - acc: 0.7032
# Epoch 5/25
# 250/250 [==============================] - 18s 72ms/step - loss: 0.5923 - acc: 0.7088
# Epoch 6/25
# 250/250 [==============================] - 18s 71ms/step - loss: 0.5887 - acc: 0.7125
# Epoch 7/25
# 250/250 [==============================] - 17s 69ms/step - loss: 0.5850 - acc: 0.7161
# Epoch 8/25
# 250/250 [==============================] - 17s 68ms/step - loss: 0.5808 - acc: 0.7203
# Epoch 9/25
# 250/250 [==============================] - 18s 70ms/step - loss: 0.5776 - acc: 0.7228
# Epoch 10/25
# 250/250 [==============================] - 12s 48ms/step - loss: 0.5737 - acc: 0.7284
# Epoch 11/25
# 250/250 [==============================] - 2s 10ms/step - loss: 0.5701 - acc: 0.7305
# Epoch 12/25
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5680 - acc: 0.7305
# Epoch 13/25
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5668 - acc: 0.7301
# Epoch 14/25
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5656 - acc: 0.7303
# Epoch 15/25
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5646 - acc: 0.7305
# Epoch 16/25
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5641 - acc: 0.7311
# Epoch 17/25
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5634 - acc: 0.7317
# Epoch 18/25
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5584 - acc: 0.7346
# Epoch 19/25
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5456 - acc: 0.7390
# Epoch 20/25
# 250/250 [==============================] - 3s 10ms/step - loss: 0.5349 - acc: 0.7408
# Epoch 21/25
# 250/250 [==============================] - 2s 10ms/step - loss: 0.5260 - acc: 0.7394
# Epoch 22/25
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5126 - acc: 0.7383
# Epoch 23/25
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5038 - acc: 0.7387
# Epoch 24/25
# 250/250 [==============================] - 3s 12ms/step - loss: 0.4980 - acc: 0.7400
# Epoch 25/25
# 250/250 [==============================] - 2s 10ms/step - loss: 0.4945 - acc: 0.7409

# %%
# evaluate the model
scores = model.evaluate(X, Y)

print("\n%s: %.5f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 768/768 [==============================] - 0s 448us/sample - loss: 0.4938 - acc: 0.7409
#
# acc: 74.08854%

# %%
# calculate predictions
predictions = model.predict(X)
#print(predictions.shape)
rounded = [round(x[0]) for x in predictions]

for i in range(predictions.shape[0]):
    p = rounded[i]
    r = Y[i]
    if p == r:
        ch='Yes'
    else:
        ch='No'
        
    print("%4.0f -> %2.4f => %2.0f => %2.0f # %s" % (i, predictions[i], p, r, ch))
# Out:
#    0 -> 0.3326 =>  0 =>  1 # No
#    1 -> 0.3319 =>  0 =>  0 # Yes
#    2 -> 0.9594 =>  1 =>  1 # Yes
#    3 -> 0.3314 =>  0 =>  0 # Yes
#    4 -> 0.7527 =>  1 =>  1 # Yes
#    5 -> 0.3326 =>  0 =>  0 # Yes
#    6 -> 0.7121 =>  1 =>  1 # Yes
#    7 -> 0.7596 =>  1 =>  0 # No
#    8 -> 0.4812 =>  0 =>  1 # No
#    9 -> 0.3324 =>  0 =>  1 # No
#   10 -> 0.3326 =>  0 =>  0 # Yes
#   11 -> 0.3323 =>  0 =>  1 # No
#   12 -> 0.0042 =>  0 =>  0 # Yes
#   13 -> 0.4812 =>  0 =>  1 # No
#   14 -> 0.7527 =>  1 =>  1 # Yes
#   15 -> 0.8961 =>  1 =>  1 # Yes
#   16 -> 0.4804 =>  0 =>  1 # No
#   17 -> 0.3326 =>  0 =>  1 # No
#   18 -> 0.0013 =>  0 =>  0 # Yes
#   19 -> 0.1900 =>  0 =>  1 # No
#   20 -> 0.0015 =>  0 =>  0 # Yes
#   21 -> 0.0022 =>  0 =>  0 # Yes
#   22 -> 0.3326 =>  0 =>  1 # No
#   23 -> 0.3326 =>  0 =>  1 # No
#   24 -> 0.7060 =>  1 =>  1 # Yes
#   25 -> 0.7527 =>  1 =>  1 # Yes
#   26 -> 0.3326 =>  0 =>  1 # No
#   27 -> 0.0012 =>  0 =>  0 # Yes
#   28 -> 0.0540 =>  0 =>  0 # Yes
#   29 -> 0.3326 =>  0 =>  0 # Yes
#   30 -> 0.3243 =>  0 =>  0 # Yes
#   31 -> 0.7343 =>  1 =>  1 # Yes
#   32 -> 0.3319 =>  0 =>  0 # Yes
#   33 -> 0.3326 =>  0 =>  0 # Yes
#   34 -> 0.3326 =>  0 =>  0 # Yes
#   35 -> 0.4812 =>  0 =>  0 # Yes
#   36 -> 0.3326 =>  0 =>  0 # Yes
#   37 -> 0.3280 =>  0 =>  1 # No
#   38 -> 0.3239 =>  0 =>  1 # No
#   39 -> 0.4751 =>  0 =>  1 # No
#   40 -> 0.0050 =>  0 =>  0 # Yes
#   41 -> 0.3326 =>  0 =>  0 # Yes
#   42 -> 0.3326 =>  0 =>  0 # Yes
#   43 -> 0.4778 =>  0 =>  1 # No
#   44 -> 0.2101 =>  0 =>  0 # Yes
#   45 -> 0.3326 =>  0 =>  1 # No
#   46 -> 0.1882 =>  0 =>  0 # Yes
#   47 -> 0.3323 =>  0 =>  0 # Yes
#   48 -> 0.3322 =>  0 =>  1 # No
#   49 -> 0.0168 =>  0 =>  0 # Yes
#   50 -> 0.3326 =>  0 =>  0 # Yes
#   51 -> 0.3233 =>  0 =>  0 # Yes
#   52 -> 0.3325 =>  0 =>  0 # Yes
#   53 -> 0.4812 =>  0 =>  1 # No
#   54 -> 0.4812 =>  0 =>  0 # Yes
#   55 -> 0.3325 =>  0 =>  0 # Yes
#   56 -> 0.7527 =>  1 =>  1 # Yes
#   57 -> 0.0020 =>  0 =>  0 # Yes
#   58 -> 0.3326 =>  0 =>  0 # Yes
#   59 -> 0.0018 =>  0 =>  0 # Yes
#   60 -> 0.0012 =>  0 =>  0 # Yes
#   61 -> 0.3326 =>  0 =>  1 # No
#   62 -> 0.0012 =>  0 =>  0 # Yes
#   63 -> 0.7527 =>  1 =>  0 # No
#   64 -> 0.3326 =>  0 =>  1 # No
#   65 -> 0.3326 =>  0 =>  0 # Yes
#   66 -> 0.3326 =>  0 =>  1 # No
#   67 -> 0.3326 =>  0 =>  0 # Yes
#   68 -> 0.3326 =>  0 =>  0 # Yes
#   69 -> 0.1665 =>  0 =>  0 # Yes
#   70 -> 0.2939 =>  0 =>  1 # No
#   71 -> 0.7527 =>  1 =>  0 # No
#   72 -> 0.3326 =>  0 =>  1 # No
#   73 -> 0.4812 =>  0 =>  0 # Yes
#   74 -> 0.3325 =>  0 =>  0 # Yes
#   75 -> 0.0012 =>  0 =>  0 # Yes
#   76 -> 0.0012 =>  0 =>  0 # Yes
#   77 -> 0.3325 =>  0 =>  0 # Yes
#   78 -> 0.9597 =>  1 =>  1 # Yes
#   79 -> 0.3326 =>  0 =>  0 # Yes
#   80 -> 0.3322 =>  0 =>  0 # Yes
#   81 -> 0.0012 =>  0 =>  0 # Yes
#   82 -> 0.3145 =>  0 =>  0 # Yes
#   83 -> 0.3326 =>  0 =>  0 # Yes
#   84 -> 0.3326 =>  0 =>  1 # No
#   85 -> 0.0113 =>  0 =>  0 # Yes
#   86 -> 0.0407 =>  0 =>  0 # Yes
#   87 -> 0.3318 =>  0 =>  0 # Yes
#   88 -> 0.7527 =>  1 =>  1 # Yes
#   89 -> 0.3326 =>  0 =>  0 # Yes
#   90 -> 0.3326 =>  0 =>  0 # Yes
#   91 -> 0.1138 =>  0 =>  0 # Yes
#   92 -> 0.0016 =>  0 =>  0 # Yes
#   93 -> 0.3298 =>  0 =>  1 # No
#   94 -> 0.3325 =>  0 =>  0 # Yes
#   95 -> 0.4812 =>  0 =>  0 # Yes
#   96 -> 0.3325 =>  0 =>  0 # Yes
#   97 -> 0.0920 =>  0 =>  0 # Yes
#   98 -> 0.0259 =>  0 =>  0 # Yes
#   99 -> 0.4811 =>  0 =>  1 # No
#  100 -> 0.3317 =>  0 =>  1 # No
#  101 -> 0.3236 =>  0 =>  0 # Yes
#  102 -> 0.3326 =>  0 =>  0 # Yes
#  103 -> 0.3326 =>  0 =>  0 # Yes
#  104 -> 0.3326 =>  0 =>  0 # Yes
#  105 -> 0.7527 =>  1 =>  0 # No
#  106 -> 0.3326 =>  0 =>  0 # Yes
#  107 -> 0.7527 =>  1 =>  0 # No
#  108 -> 0.3077 =>  0 =>  0 # Yes
#  109 -> 0.3326 =>  0 =>  1 # No
#  110 -> 0.7527 =>  1 =>  1 # Yes
#  111 -> 0.4812 =>  0 =>  1 # No
#  112 -> 0.3312 =>  0 =>  0 # Yes
#  113 -> 0.3326 =>  0 =>  0 # Yes
#  114 -> 0.7527 =>  1 =>  1 # Yes
#  115 -> 0.3326 =>  0 =>  1 # No
#  116 -> 0.3326 =>  0 =>  1 # No
#  117 -> 0.3325 =>  0 =>  0 # Yes
#  118 -> 0.3326 =>  0 =>  0 # Yes
#  119 -> 0.3326 =>  0 =>  0 # Yes
#  120 -> 0.3270 =>  0 =>  1 # No
#  121 -> 0.3325 =>  0 =>  0 # Yes
#  122 -> 0.3312 =>  0 =>  0 # Yes
#  123 -> 0.0012 =>  0 =>  0 # Yes
#  124 -> 0.3326 =>  0 =>  1 # No
#  125 -> 0.7506 =>  1 =>  1 # Yes
#  126 -> 0.0012 =>  0 =>  0 # Yes
#  127 -> 0.0359 =>  0 =>  0 # Yes
#  128 -> 0.2400 =>  0 =>  1 # No
#  129 -> 0.3194 =>  0 =>  1 # No
#  130 -> 0.7527 =>  1 =>  1 # Yes
#  131 -> 0.3166 =>  0 =>  1 # No
#  132 -> 0.7527 =>  1 =>  1 # Yes
#  133 -> 0.3170 =>  0 =>  0 # Yes
#  134 -> 0.3326 =>  0 =>  0 # Yes
#  135 -> 0.1003 =>  0 =>  0 # Yes
#  136 -> 0.3326 =>  0 =>  0 # Yes
#  137 -> 0.2152 =>  0 =>  0 # Yes
#  138 -> 0.3326 =>  0 =>  0 # Yes
#  139 -> 0.4812 =>  0 =>  0 # Yes
#  140 -> 0.3326 =>  0 =>  0 # Yes
#  141 -> 0.3326 =>  0 =>  0 # Yes
#  142 -> 0.1266 =>  0 =>  0 # Yes
#  143 -> 0.3324 =>  0 =>  1 # No
#  144 -> 0.4858 =>  0 =>  0 # Yes
#  145 -> 0.3326 =>  0 =>  0 # Yes
#  146 -> 0.0020 =>  0 =>  0 # Yes
#  147 -> 0.0015 =>  0 =>  0 # Yes
#  148 -> 0.3317 =>  0 =>  0 # Yes
#  149 -> 0.3326 =>  0 =>  0 # Yes
#  150 -> 0.0114 =>  0 =>  0 # Yes
#  151 -> 0.3326 =>  0 =>  0 # Yes
#  152 -> 0.7527 =>  1 =>  1 # Yes
#  153 -> 0.4812 =>  0 =>  0 # Yes
#  154 -> 0.3249 =>  0 =>  1 # No
#  155 -> 0.3326 =>  0 =>  1 # No
#  156 -> 0.0012 =>  0 =>  0 # Yes
#  157 -> 0.0012 =>  0 =>  0 # Yes
#  158 -> 0.3326 =>  0 =>  0 # Yes
#  159 -> 0.7527 =>  1 =>  1 # Yes
#  160 -> 0.3326 =>  0 =>  0 # Yes
#  161 -> 0.0295 =>  0 =>  0 # Yes
#  162 -> 0.4812 =>  0 =>  0 # Yes
#  163 -> 0.3326 =>  0 =>  0 # Yes
#  164 -> 0.3326 =>  0 =>  1 # No
#  165 -> 0.3861 =>  0 =>  1 # No
#  166 -> 0.3326 =>  0 =>  0 # Yes
#  167 -> 0.3326 =>  0 =>  0 # Yes
#  168 -> 0.3326 =>  0 =>  0 # Yes
#  169 -> 0.3326 =>  0 =>  0 # Yes
#  170 -> 0.3326 =>  0 =>  1 # No
#  171 -> 0.7491 =>  1 =>  1 # Yes
#  172 -> 0.0012 =>  0 =>  0 # Yes
#  173 -> 0.0027 =>  0 =>  0 # Yes
#  174 -> 0.2835 =>  0 =>  0 # Yes
#  175 -> 0.7527 =>  1 =>  1 # Yes
#  176 -> 0.3314 =>  0 =>  0 # Yes
#  177 -> 0.3326 =>  0 =>  1 # No
#  178 -> 0.3326 =>  0 =>  0 # Yes
#  179 -> 0.3326 =>  0 =>  1 # No
#  180 -> 0.3326 =>  0 =>  0 # Yes
#  181 -> 0.0019 =>  0 =>  0 # Yes
#  182 -> 0.0012 =>  0 =>  0 # Yes
#  183 -> 0.3326 =>  0 =>  0 # Yes
#  184 -> 0.3326 =>  0 =>  0 # Yes
#  185 -> 0.3326 =>  0 =>  1 # No
#  186 -> 0.4812 =>  0 =>  1 # No
#  187 -> 0.3326 =>  0 =>  1 # No
#  188 -> 0.7105 =>  1 =>  1 # Yes
#  189 -> 0.7521 =>  1 =>  1 # Yes
#  190 -> 0.3326 =>  0 =>  0 # Yes
#  191 -> 0.0124 =>  0 =>  0 # Yes
#  192 -> 0.3127 =>  0 =>  1 # No
#  193 -> 0.7635 =>  1 =>  1 # Yes
#  194 -> 0.2967 =>  0 =>  0 # Yes
#  195 -> 0.7527 =>  1 =>  1 # Yes
#  196 -> 0.3326 =>  0 =>  0 # Yes
#  197 -> 0.3317 =>  0 =>  1 # No
#  198 -> 0.7202 =>  1 =>  1 # Yes
#  199 -> 0.4812 =>  0 =>  1 # No
#  200 -> 0.3326 =>  0 =>  0 # Yes
#  201 -> 0.3326 =>  0 =>  0 # Yes
#  202 -> 0.3326 =>  0 =>  0 # Yes
#  203 -> 0.3326 =>  0 =>  0 # Yes
#  204 -> 0.4812 =>  0 =>  0 # Yes
#  205 -> 0.3326 =>  0 =>  0 # Yes
#  206 -> 0.7527 =>  1 =>  1 # Yes
#  207 -> 0.3326 =>  0 =>  1 # No
#  208 -> 0.3291 =>  0 =>  0 # Yes
#  209 -> 0.3326 =>  0 =>  1 # No
#  210 -> 0.3323 =>  0 =>  0 # Yes
#  211 -> 0.3326 =>  0 =>  0 # Yes
#  212 -> 0.3326 =>  0 =>  0 # Yes
#  213 -> 0.6795 =>  1 =>  1 # Yes
#  214 -> 0.4755 =>  0 =>  1 # No
#  215 -> 0.7446 =>  1 =>  1 # Yes
#  216 -> 0.7527 =>  1 =>  1 # Yes
#  217 -> 0.7527 =>  1 =>  0 # No
#  218 -> 0.3326 =>  0 =>  1 # No
#  219 -> 0.3326 =>  0 =>  1 # No
#  220 -> 0.4812 =>  0 =>  1 # No
#  221 -> 0.3326 =>  0 =>  1 # No
#  222 -> 0.0043 =>  0 =>  0 # Yes
#  223 -> 0.0020 =>  0 =>  0 # Yes
#  224 -> 0.3326 =>  0 =>  0 # Yes
#  225 -> 0.3325 =>  0 =>  0 # Yes
#  226 -> 0.3326 =>  0 =>  0 # Yes
#  227 -> 0.3326 =>  0 =>  1 # No
#  228 -> 0.4812 =>  0 =>  0 # Yes
#  229 -> 0.3326 =>  0 =>  0 # Yes
#  230 -> 0.3326 =>  0 =>  1 # No
#  231 -> 0.4812 =>  0 =>  1 # No
#  232 -> 0.3326 =>  0 =>  0 # Yes
#  233 -> 0.3326 =>  0 =>  0 # Yes
#  234 -> 0.2781 =>  0 =>  0 # Yes
#  235 -> 0.3323 =>  0 =>  1 # No
#  236 -> 0.7527 =>  1 =>  1 # Yes
#  237 -> 0.3326 =>  0 =>  1 # No
#  238 -> 0.3326 =>  0 =>  1 # No
#  239 -> 0.3326 =>  0 =>  0 # Yes
#  240 -> 0.3326 =>  0 =>  0 # Yes
#  241 -> 0.2406 =>  0 =>  0 # Yes
#  242 -> 0.2868 =>  0 =>  1 # No
#  243 -> 0.7527 =>  1 =>  1 # Yes
#  244 -> 0.7493 =>  1 =>  0 # No
#  245 -> 0.3326 =>  0 =>  1 # No
#  246 -> 0.3326 =>  0 =>  0 # Yes
#  247 -> 0.4812 =>  0 =>  0 # Yes
#  248 -> 0.4812 =>  0 =>  0 # Yes
#  249 -> 0.3326 =>  0 =>  0 # Yes
#  250 -> 0.0075 =>  0 =>  0 # Yes
#  251 -> 0.3326 =>  0 =>  0 # Yes
#  252 -> 0.3326 =>  0 =>  0 # Yes
#  253 -> 0.3322 =>  0 =>  0 # Yes
#  254 -> 0.4812 =>  0 =>  1 # No
#  255 -> 0.3326 =>  0 =>  1 # No
#  256 -> 0.3316 =>  0 =>  0 # Yes
#  257 -> 0.3326 =>  0 =>  0 # Yes
#  258 -> 0.4812 =>  0 =>  0 # Yes
#  259 -> 0.7527 =>  1 =>  1 # Yes
#  260 -> 0.7527 =>  1 =>  0 # No
#  261 -> 0.9597 =>  1 =>  1 # Yes
#  262 -> 0.3326 =>  0 =>  0 # Yes
#  263 -> 0.3326 =>  0 =>  0 # Yes
#  264 -> 0.3324 =>  0 =>  1 # No
#  265 -> 0.3324 =>  0 =>  0 # Yes
#  266 -> 0.9597 =>  1 =>  1 # Yes
#  267 -> 0.3326 =>  0 =>  0 # Yes
#  268 -> 0.3325 =>  0 =>  0 # Yes
#  269 -> 0.9597 =>  1 =>  1 # Yes
#  270 -> 0.3319 =>  0 =>  1 # No
#  271 -> 0.3320 =>  0 =>  0 # Yes
#  272 -> 0.3326 =>  0 =>  0 # Yes
#  273 -> 0.0016 =>  0 =>  0 # Yes
#  274 -> 0.0012 =>  0 =>  0 # Yes
#  275 -> 0.0052 =>  0 =>  0 # Yes
#  276 -> 0.3326 =>  0 =>  1 # No
#  277 -> 0.0014 =>  0 =>  0 # Yes
#  278 -> 0.0359 =>  0 =>  0 # Yes
#  279 -> 0.4812 =>  0 =>  0 # Yes
#  280 -> 0.3326 =>  0 =>  1 # No
#  281 -> 0.7527 =>  1 =>  0 # No
#  282 -> 0.0012 =>  0 =>  0 # Yes
#  283 -> 0.3326 =>  0 =>  1 # No
#  284 -> 0.3326 =>  0 =>  1 # No
#  285 -> 0.7527 =>  1 =>  0 # No
#  286 -> 0.4812 =>  0 =>  0 # Yes
#  287 -> 0.4812 =>  0 =>  1 # No
#  288 -> 0.3305 =>  0 =>  0 # Yes
#  289 -> 0.0408 =>  0 =>  0 # Yes
#  290 -> 0.3326 =>  0 =>  0 # Yes
#  291 -> 0.3254 =>  0 =>  1 # No
#  292 -> 0.4794 =>  0 =>  1 # No
#  293 -> 0.7527 =>  1 =>  1 # Yes
#  294 -> 0.0012 =>  0 =>  0 # Yes
#  295 -> 0.7527 =>  1 =>  0 # No
#  296 -> 0.4812 =>  0 =>  1 # No
#  297 -> 0.0012 =>  0 =>  0 # Yes
#  298 -> 0.4812 =>  0 =>  1 # No
#  299 -> 0.0012 =>  0 =>  0 # Yes
#  300 -> 0.9597 =>  1 =>  1 # Yes
#  301 -> 0.7527 =>  1 =>  1 # Yes
#  302 -> 0.0151 =>  0 =>  0 # Yes
#  303 -> 0.3326 =>  0 =>  1 # No
#  304 -> 0.3326 =>  0 =>  0 # Yes
#  305 -> 0.3073 =>  0 =>  0 # Yes
#  306 -> 0.7527 =>  1 =>  1 # Yes
#  307 -> 0.0012 =>  0 =>  0 # Yes
#  308 -> 0.4703 =>  0 =>  1 # No
#  309 -> 0.4812 =>  0 =>  1 # No
#  310 -> 0.2781 =>  0 =>  0 # Yes
#  311 -> 0.0014 =>  0 =>  0 # Yes
#  312 -> 0.7109 =>  1 =>  1 # Yes
#  313 -> 0.0214 =>  0 =>  0 # Yes
#  314 -> 0.3325 =>  0 =>  1 # No
#  315 -> 0.1037 =>  0 =>  0 # Yes
#  316 -> 0.3326 =>  0 =>  0 # Yes
#  317 -> 0.3310 =>  0 =>  1 # No
#  318 -> 0.7520 =>  1 =>  0 # No
#  319 -> 0.9498 =>  1 =>  1 # Yes
#  320 -> 0.4812 =>  0 =>  0 # Yes
#  321 -> 0.3326 =>  0 =>  1 # No
#  322 -> 0.3326 =>  0 =>  1 # No
#  323 -> 0.3326 =>  0 =>  1 # No
#  324 -> 0.3326 =>  0 =>  0 # Yes
#  325 -> 0.7527 =>  1 =>  0 # No
#  326 -> 0.6792 =>  1 =>  1 # Yes
#  327 -> 0.3421 =>  0 =>  0 # Yes
#  328 -> 0.3319 =>  0 =>  1 # No
#  329 -> 0.3145 =>  0 =>  0 # Yes
#  330 -> 0.3326 =>  0 =>  0 # Yes
#  331 -> 0.3324 =>  0 =>  0 # Yes
#  332 -> 0.9597 =>  1 =>  1 # Yes
#  333 -> 0.0015 =>  0 =>  0 # Yes
#  334 -> 0.3320 =>  0 =>  0 # Yes
#  335 -> 0.0012 =>  0 =>  0 # Yes
#  336 -> 0.0012 =>  0 =>  0 # Yes
#  337 -> 0.3326 =>  0 =>  1 # No
#  338 -> 0.7527 =>  1 =>  1 # Yes
#  339 -> 0.3326 =>  0 =>  1 # No
#  340 -> 0.0013 =>  0 =>  0 # Yes
#  341 -> 0.3326 =>  0 =>  0 # Yes
#  342 -> 0.0013 =>  0 =>  0 # Yes
#  343 -> 0.3326 =>  0 =>  0 # Yes
#  344 -> 0.0012 =>  0 =>  0 # Yes
#  345 -> 0.3112 =>  0 =>  0 # Yes
#  346 -> 0.7527 =>  1 =>  0 # No
#  347 -> 0.9595 =>  1 =>  0 # No
#  348 -> 0.2444 =>  0 =>  0 # Yes
#  349 -> 0.7526 =>  1 =>  1 # Yes
#  350 -> 0.3326 =>  0 =>  0 # Yes
#  351 -> 0.3326 =>  0 =>  0 # Yes
#  352 -> 0.0012 =>  0 =>  0 # Yes
#  353 -> 0.3326 =>  0 =>  0 # Yes
#  354 -> 0.3326 =>  0 =>  0 # Yes
#  355 -> 0.3326 =>  0 =>  1 # No
#  356 -> 0.7527 =>  1 =>  1 # Yes
#  357 -> 0.9320 =>  1 =>  1 # Yes
#  358 -> 0.0015 =>  0 =>  0 # Yes
#  359 -> 0.7527 =>  1 =>  1 # Yes
#  360 -> 0.7527 =>  1 =>  1 # Yes
#  361 -> 0.0119 =>  0 =>  0 # Yes
#  362 -> 0.3321 =>  0 =>  0 # Yes
#  363 -> 0.3312 =>  0 =>  1 # No
#  364 -> 0.4812 =>  0 =>  0 # Yes
#  365 -> 0.0018 =>  0 =>  0 # Yes
#  366 -> 0.3326 =>  0 =>  1 # No
#  367 -> 0.3326 =>  0 =>  0 # Yes
#  368 -> 0.3326 =>  0 =>  0 # Yes
#  369 -> 0.3325 =>  0 =>  1 # No
#  370 -> 0.4812 =>  0 =>  1 # No
#  371 -> 0.0015 =>  0 =>  0 # Yes
#  372 -> 0.3324 =>  0 =>  0 # Yes
#  373 -> 0.0121 =>  0 =>  0 # Yes
#  374 -> 0.7527 =>  1 =>  0 # No
#  375 -> 0.4812 =>  0 =>  1 # No
#  376 -> 0.3326 =>  0 =>  0 # Yes
#  377 -> 0.0047 =>  0 =>  0 # Yes
#  378 -> 0.3326 =>  0 =>  1 # No
#  379 -> 0.3316 =>  0 =>  0 # Yes
#  380 -> 0.3319 =>  0 =>  0 # Yes
#  381 -> 0.3326 =>  0 =>  0 # Yes
#  382 -> 0.4812 =>  0 =>  0 # Yes
#  383 -> 0.3321 =>  0 =>  0 # Yes
#  384 -> 0.0013 =>  0 =>  0 # Yes
#  385 -> 0.0167 =>  0 =>  0 # Yes
#  386 -> 0.3326 =>  0 =>  1 # No
#  387 -> 0.3326 =>  0 =>  1 # No
#  388 -> 0.4812 =>  0 =>  1 # No
#  389 -> 0.3310 =>  0 =>  0 # Yes
#  390 -> 0.4812 =>  0 =>  0 # Yes
#  391 -> 0.3326 =>  0 =>  1 # No
#  392 -> 0.4812 =>  0 =>  0 # Yes
#  393 -> 0.0198 =>  0 =>  0 # Yes
#  394 -> 0.3326 =>  0 =>  1 # No
#  395 -> 0.4812 =>  0 =>  0 # Yes
#  396 -> 0.0012 =>  0 =>  0 # Yes
#  397 -> 0.3326 =>  0 =>  1 # No
#  398 -> 0.3326 =>  0 =>  0 # Yes
#  399 -> 0.3326 =>  0 =>  1 # No
#  400 -> 0.3326 =>  0 =>  1 # No
#  401 -> 0.0179 =>  0 =>  0 # Yes
#  402 -> 0.3322 =>  0 =>  1 # No
#  403 -> 0.3287 =>  0 =>  0 # Yes
#  404 -> 0.8427 =>  1 =>  1 # Yes
#  405 -> 0.7527 =>  1 =>  0 # No
#  406 -> 0.3326 =>  0 =>  1 # No
#  407 -> 0.3326 =>  0 =>  0 # Yes
#  408 -> 0.9593 =>  1 =>  1 # Yes
#  409 -> 0.4812 =>  0 =>  1 # No
#  410 -> 0.3326 =>  0 =>  0 # Yes
#  411 -> 0.4799 =>  0 =>  0 # Yes
#  412 -> 0.4812 =>  0 =>  0 # Yes
#  413 -> 0.3321 =>  0 =>  0 # Yes
#  414 -> 0.7527 =>  1 =>  1 # Yes
#  415 -> 0.4812 =>  0 =>  1 # No
#  416 -> 0.3326 =>  0 =>  0 # Yes
#  417 -> 0.3326 =>  0 =>  1 # No
#  418 -> 0.3326 =>  0 =>  0 # Yes
#  419 -> 0.7527 =>  1 =>  1 # Yes
#  420 -> 0.0567 =>  0 =>  0 # Yes
#  421 -> 0.3325 =>  0 =>  0 # Yes
#  422 -> 0.0379 =>  0 =>  0 # Yes
#  423 -> 0.3326 =>  0 =>  0 # Yes
#  424 -> 0.7447 =>  1 =>  1 # Yes
#  425 -> 0.7527 =>  1 =>  1 # Yes
#  426 -> 0.0012 =>  0 =>  0 # Yes
#  427 -> 0.7527 =>  1 =>  1 # Yes
#  428 -> 0.3309 =>  0 =>  0 # Yes
#  429 -> 0.4812 =>  0 =>  1 # No
#  430 -> 0.0015 =>  0 =>  0 # Yes
#  431 -> 0.3326 =>  0 =>  0 # Yes
#  432 -> 0.3326 =>  0 =>  0 # Yes
#  433 -> 0.3326 =>  0 =>  0 # Yes
#  434 -> 0.3326 =>  0 =>  0 # Yes
#  435 -> 0.9597 =>  1 =>  1 # Yes
#  436 -> 0.3326 =>  0 =>  0 # Yes
#  437 -> 0.3326 =>  0 =>  0 # Yes
#  438 -> 0.3326 =>  0 =>  0 # Yes
#  439 -> 0.3326 =>  0 =>  0 # Yes
#  440 -> 0.3326 =>  0 =>  1 # No
#  441 -> 0.3316 =>  0 =>  0 # Yes
#  442 -> 0.0373 =>  0 =>  0 # Yes
#  443 -> 0.3326 =>  0 =>  1 # No
#  444 -> 0.3326 =>  0 =>  1 # No
#  445 -> 0.3326 =>  0 =>  1 # No
#  446 -> 0.3326 =>  0 =>  0 # Yes
#  447 -> 0.0154 =>  0 =>  0 # Yes
#  448 -> 0.3113 =>  0 =>  1 # No
#  449 -> 0.3326 =>  0 =>  0 # Yes
#  450 -> 0.3259 =>  0 =>  0 # Yes
#  451 -> 0.3326 =>  0 =>  1 # No
#  452 -> 0.4812 =>  0 =>  0 # Yes
#  453 -> 0.0012 =>  0 =>  0 # Yes
#  454 -> 0.0013 =>  0 =>  0 # Yes
#  455 -> 0.3326 =>  0 =>  1 # No
#  456 -> 0.0012 =>  0 =>  0 # Yes
#  457 -> 0.2695 =>  0 =>  0 # Yes
#  458 -> 0.7527 =>  1 =>  1 # Yes
#  459 -> 0.0088 =>  0 =>  0 # Yes
#  460 -> 0.3324 =>  0 =>  0 # Yes
#  461 -> 0.3326 =>  0 =>  0 # Yes
#  462 -> 0.0016 =>  0 =>  0 # Yes
#  463 -> 0.3324 =>  0 =>  0 # Yes
#  464 -> 0.3326 =>  0 =>  0 # Yes
#  465 -> 0.0186 =>  0 =>  0 # Yes
#  466 -> 0.3326 =>  0 =>  0 # Yes
#  467 -> 0.0294 =>  0 =>  0 # Yes
#  468 -> 0.9454 =>  1 =>  1 # Yes
#  469 -> 0.7527 =>  1 =>  0 # No
#  470 -> 0.3326 =>  0 =>  0 # Yes
#  471 -> 0.3326 =>  0 =>  0 # Yes
#  472 -> 0.3326 =>  0 =>  0 # Yes
#  473 -> 0.3326 =>  0 =>  0 # Yes
#  474 -> 0.3326 =>  0 =>  0 # Yes
#  475 -> 0.3326 =>  0 =>  0 # Yes
#  476 -> 0.4761 =>  0 =>  1 # No
#  477 -> 0.0023 =>  0 =>  0 # Yes
#  478 -> 0.3309 =>  0 =>  0 # Yes
#  479 -> 0.3326 =>  0 =>  0 # Yes
#  480 -> 0.4812 =>  0 =>  1 # No
#  481 -> 0.3326 =>  0 =>  0 # Yes
#  482 -> 0.3220 =>  0 =>  0 # Yes
#  483 -> 0.3325 =>  0 =>  0 # Yes
#  484 -> 0.9597 =>  1 =>  1 # Yes
#  485 -> 0.4742 =>  0 =>  1 # No
#  486 -> 0.4812 =>  0 =>  0 # Yes
#  487 -> 0.4812 =>  0 =>  0 # Yes
#  488 -> 0.3326 =>  0 =>  0 # Yes
#  489 -> 0.0187 =>  0 =>  0 # Yes
#  490 -> 0.2816 =>  0 =>  0 # Yes
#  491 -> 0.3325 =>  0 =>  0 # Yes
#  492 -> 0.3313 =>  0 =>  0 # Yes
#  493 -> 0.7184 =>  1 =>  1 # Yes
#  494 -> 0.0012 =>  0 =>  0 # Yes
#  495 -> 0.0184 =>  0 =>  0 # Yes
#  496 -> 0.3326 =>  0 =>  0 # Yes
#  497 -> 0.3326 =>  0 =>  0 # Yes
#  498 -> 0.7527 =>  1 =>  1 # Yes
#  499 -> 0.7527 =>  1 =>  0 # No
#  500 -> 0.3326 =>  0 =>  0 # Yes
#  501 -> 0.3318 =>  0 =>  0 # Yes
#  502 -> 0.7527 =>  1 =>  1 # Yes
#  503 -> 0.0935 =>  0 =>  0 # Yes
#  504 -> 0.3293 =>  0 =>  0 # Yes
#  505 -> 0.0012 =>  0 =>  0 # Yes
#  506 -> 0.2901 =>  0 =>  1 # No
#  507 -> 0.0016 =>  0 =>  0 # Yes
#  508 -> 0.0217 =>  0 =>  0 # Yes
#  509 -> 0.0012 =>  0 =>  0 # Yes
#  510 -> 0.2648 =>  0 =>  1 # No
#  511 -> 0.0012 =>  0 =>  0 # Yes
#  512 -> 0.0012 =>  0 =>  0 # Yes
#  513 -> 0.3326 =>  0 =>  0 # Yes
#  514 -> 0.0013 =>  0 =>  0 # Yes
#  515 -> 0.7527 =>  1 =>  1 # Yes
#  516 -> 0.7527 =>  1 =>  1 # Yes
#  517 -> 0.3326 =>  0 =>  0 # Yes
#  518 -> 0.0012 =>  0 =>  0 # Yes
#  519 -> 0.4812 =>  0 =>  0 # Yes
#  520 -> 0.1110 =>  0 =>  0 # Yes
#  521 -> 0.0049 =>  0 =>  0 # Yes
#  522 -> 0.0015 =>  0 =>  0 # Yes
#  523 -> 0.3326 =>  0 =>  1 # No
#  524 -> 0.3323 =>  0 =>  0 # Yes
#  525 -> 0.3326 =>  0 =>  0 # Yes
#  526 -> 0.3124 =>  0 =>  0 # Yes
#  527 -> 0.0255 =>  0 =>  0 # Yes
#  528 -> 0.0012 =>  0 =>  0 # Yes
#  529 -> 0.3326 =>  0 =>  0 # Yes
#  530 -> 0.0014 =>  0 =>  0 # Yes
#  531 -> 0.3326 =>  0 =>  0 # Yes
#  532 -> 0.0013 =>  0 =>  0 # Yes
#  533 -> 0.0015 =>  0 =>  0 # Yes
#  534 -> 0.0060 =>  0 =>  0 # Yes
#  535 -> 0.9597 =>  1 =>  1 # Yes
#  536 -> 0.3326 =>  0 =>  0 # Yes
#  537 -> 0.0012 =>  0 =>  0 # Yes
#  538 -> 0.0012 =>  0 =>  0 # Yes
#  539 -> 0.1937 =>  0 =>  1 # No
#  540 -> 0.4812 =>  0 =>  1 # No
#  541 -> 0.4810 =>  0 =>  1 # No
#  542 -> 0.2983 =>  0 =>  1 # No
#  543 -> 0.3326 =>  0 =>  0 # Yes
#  544 -> 0.3319 =>  0 =>  0 # Yes
#  545 -> 0.7527 =>  1 =>  1 # Yes
#  546 -> 0.7527 =>  1 =>  1 # Yes
#  547 -> 0.0079 =>  0 =>  0 # Yes
#  548 -> 0.3326 =>  0 =>  0 # Yes
#  549 -> 0.3326 =>  0 =>  0 # Yes
#  550 -> 0.3326 =>  0 =>  0 # Yes
#  551 -> 0.2547 =>  0 =>  0 # Yes
#  552 -> 0.0012 =>  0 =>  0 # Yes
#  553 -> 0.3315 =>  0 =>  0 # Yes
#  554 -> 0.2230 =>  0 =>  0 # Yes
#  555 -> 0.4812 =>  0 =>  0 # Yes
#  556 -> 0.3311 =>  0 =>  0 # Yes
#  557 -> 0.0012 =>  0 =>  0 # Yes
#  558 -> 0.2064 =>  0 =>  0 # Yes
#  559 -> 0.0143 =>  0 =>  0 # Yes
#  560 -> 0.3326 =>  0 =>  1 # No
#  561 -> 0.7527 =>  1 =>  1 # Yes
#  562 -> 0.1292 =>  0 =>  0 # Yes
#  563 -> 0.3313 =>  0 =>  0 # Yes
#  564 -> 0.3326 =>  0 =>  0 # Yes
#  565 -> 0.0013 =>  0 =>  0 # Yes
#  566 -> 0.3326 =>  0 =>  0 # Yes
#  567 -> 0.0019 =>  0 =>  0 # Yes
#  568 -> 0.7527 =>  1 =>  0 # No
#  569 -> 0.4536 =>  0 =>  1 # No
#  570 -> 0.3326 =>  0 =>  0 # Yes
#  571 -> 0.3326 =>  0 =>  0 # Yes
#  572 -> 0.3323 =>  0 =>  0 # Yes
#  573 -> 0.0012 =>  0 =>  0 # Yes
#  574 -> 0.4812 =>  0 =>  0 # Yes
#  575 -> 0.0136 =>  0 =>  0 # Yes
#  576 -> 0.7527 =>  1 =>  0 # No
#  577 -> 0.3326 =>  0 =>  1 # No
#  578 -> 0.3326 =>  0 =>  0 # Yes
#  579 -> 0.3306 =>  0 =>  1 # No
#  580 -> 0.3326 =>  0 =>  1 # No
#  581 -> 0.3326 =>  0 =>  0 # Yes
#  582 -> 0.0013 =>  0 =>  0 # Yes
#  583 -> 0.3326 =>  0 =>  0 # Yes
#  584 -> 0.4812 =>  0 =>  1 # No
#  585 -> 0.3326 =>  0 =>  0 # Yes
#  586 -> 0.3301 =>  0 =>  1 # No
#  587 -> 0.3326 =>  0 =>  0 # Yes
#  588 -> 0.7527 =>  1 =>  1 # Yes
#  589 -> 0.0012 =>  0 =>  0 # Yes
#  590 -> 0.3312 =>  0 =>  1 # No
#  591 -> 0.0327 =>  0 =>  0 # Yes
#  592 -> 0.3326 =>  0 =>  1 # No
#  593 -> 0.0337 =>  0 =>  0 # Yes
#  594 -> 0.4812 =>  0 =>  0 # Yes
#  595 -> 0.7406 =>  1 =>  1 # Yes
#  596 -> 0.3326 =>  0 =>  0 # Yes
#  597 -> 0.0014 =>  0 =>  0 # Yes
#  598 -> 0.3307 =>  0 =>  1 # No
#  599 -> 0.7527 =>  1 =>  0 # No
#  600 -> 0.3326 =>  0 =>  0 # Yes
#  601 -> 0.0732 =>  0 =>  0 # Yes
#  602 -> 0.3326 =>  0 =>  0 # Yes
#  603 -> 0.7520 =>  1 =>  1 # Yes
#  604 -> 0.9597 =>  1 =>  1 # Yes
#  605 -> 0.3326 =>  0 =>  0 # Yes
#  606 -> 0.7527 =>  1 =>  1 # Yes
#  607 -> 0.3325 =>  0 =>  0 # Yes
#  608 -> 0.0129 =>  0 =>  0 # Yes
#  609 -> 0.4784 =>  0 =>  0 # Yes
#  610 -> 0.4812 =>  0 =>  0 # Yes
#  611 -> 0.7527 =>  1 =>  1 # Yes
#  612 -> 0.4812 =>  0 =>  1 # No
#  613 -> 0.3326 =>  0 =>  0 # Yes
#  614 -> 0.7527 =>  1 =>  1 # Yes
#  615 -> 0.3326 =>  0 =>  0 # Yes
#  616 -> 0.3326 =>  0 =>  0 # Yes
#  617 -> 0.3325 =>  0 =>  0 # Yes
#  618 -> 0.3326 =>  0 =>  1 # No
#  619 -> 0.9421 =>  1 =>  1 # Yes
#  620 -> 0.1868 =>  0 =>  0 # Yes
#  621 -> 0.3326 =>  0 =>  0 # Yes
#  622 -> 0.3326 =>  0 =>  0 # Yes
#  623 -> 0.3307 =>  0 =>  0 # Yes
#  624 -> 0.3326 =>  0 =>  0 # Yes
#  625 -> 0.0609 =>  0 =>  0 # Yes
#  626 -> 0.3326 =>  0 =>  0 # Yes
#  627 -> 0.3326 =>  0 =>  0 # Yes
#  628 -> 0.3326 =>  0 =>  0 # Yes
#  629 -> 0.3326 =>  0 =>  0 # Yes
#  630 -> 0.3326 =>  0 =>  1 # No
#  631 -> 0.2845 =>  0 =>  0 # Yes
#  632 -> 0.3326 =>  0 =>  0 # Yes
#  633 -> 0.0013 =>  0 =>  0 # Yes
#  634 -> 0.3326 =>  0 =>  0 # Yes
#  635 -> 0.3202 =>  0 =>  1 # No
#  636 -> 0.3326 =>  0 =>  0 # Yes
#  637 -> 0.3326 =>  0 =>  0 # Yes
#  638 -> 0.1339 =>  0 =>  1 # No
#  639 -> 0.3326 =>  0 =>  0 # Yes
#  640 -> 0.3326 =>  0 =>  0 # Yes
#  641 -> 0.3326 =>  0 =>  0 # Yes
#  642 -> 0.3326 =>  0 =>  1 # No
#  643 -> 0.0012 =>  0 =>  0 # Yes
#  644 -> 0.0013 =>  0 =>  0 # Yes
#  645 -> 0.4812 =>  0 =>  0 # Yes
#  646 -> 0.7527 =>  1 =>  1 # Yes
#  647 -> 0.7527 =>  1 =>  1 # Yes
#  648 -> 0.7526 =>  1 =>  1 # Yes
#  649 -> 0.3326 =>  0 =>  0 # Yes
#  650 -> 0.0013 =>  0 =>  0 # Yes
#  651 -> 0.0013 =>  0 =>  0 # Yes
#  652 -> 0.3269 =>  0 =>  0 # Yes
#  653 -> 0.3293 =>  0 =>  0 # Yes
#  654 -> 0.0015 =>  0 =>  0 # Yes
#  655 -> 0.4812 =>  0 =>  1 # No
#  656 -> 0.0340 =>  0 =>  0 # Yes
#  657 -> 0.0192 =>  0 =>  0 # Yes
#  658 -> 0.3326 =>  0 =>  0 # Yes
#  659 -> 0.3190 =>  0 =>  1 # No
#  660 -> 0.3326 =>  0 =>  0 # Yes
#  661 -> 0.3326 =>  0 =>  1 # No
#  662 -> 0.7523 =>  1 =>  1 # Yes
#  663 -> 0.7526 =>  1 =>  1 # Yes
#  664 -> 0.3266 =>  0 =>  1 # No
#  665 -> 0.1211 =>  0 =>  0 # Yes
#  666 -> 0.3326 =>  0 =>  1 # No
#  667 -> 0.3326 =>  0 =>  1 # No
#  668 -> 0.4812 =>  0 =>  0 # Yes
#  669 -> 0.0014 =>  0 =>  0 # Yes
#  670 -> 0.7527 =>  1 =>  0 # No
#  671 -> 0.3326 =>  0 =>  0 # Yes
#  672 -> 0.0012 =>  0 =>  0 # Yes
#  673 -> 0.4811 =>  0 =>  0 # Yes
#  674 -> 0.0012 =>  0 =>  0 # Yes
#  675 -> 0.9586 =>  1 =>  1 # Yes
#  676 -> 0.3326 =>  0 =>  1 # No
#  677 -> 0.3326 =>  0 =>  0 # Yes
#  678 -> 0.3241 =>  0 =>  1 # No
#  679 -> 0.4812 =>  0 =>  0 # Yes
#  680 -> 0.0026 =>  0 =>  0 # Yes
#  681 -> 0.3326 =>  0 =>  1 # No
#  682 -> 0.0032 =>  0 =>  0 # Yes
#  683 -> 0.3326 =>  0 =>  1 # No
#  684 -> 0.0012 =>  0 =>  0 # Yes
#  685 -> 0.0078 =>  0 =>  0 # Yes
#  686 -> 0.3326 =>  0 =>  0 # Yes
#  687 -> 0.3326 =>  0 =>  0 # Yes
#  688 -> 0.0012 =>  0 =>  0 # Yes
#  689 -> 0.7516 =>  1 =>  1 # Yes
#  690 -> 0.3326 =>  0 =>  0 # Yes
#  691 -> 0.3326 =>  0 =>  1 # No
#  692 -> 0.1568 =>  0 =>  0 # Yes
#  693 -> 0.7523 =>  1 =>  1 # Yes
#  694 -> 0.3326 =>  0 =>  0 # Yes
#  695 -> 0.4812 =>  0 =>  1 # No
#  696 -> 0.7527 =>  1 =>  1 # Yes
#  697 -> 0.0013 =>  0 =>  0 # Yes
#  698 -> 0.0013 =>  0 =>  0 # Yes
#  699 -> 0.3326 =>  0 =>  0 # Yes
#  700 -> 0.4805 =>  0 =>  0 # Yes
#  701 -> 0.3326 =>  0 =>  1 # No
#  702 -> 0.3326 =>  0 =>  1 # No
#  703 -> 0.0012 =>  0 =>  0 # Yes
#  704 -> 0.3164 =>  0 =>  0 # Yes
#  705 -> 0.3276 =>  0 =>  0 # Yes
#  706 -> 0.9176 =>  1 =>  1 # Yes
#  707 -> 0.4812 =>  0 =>  0 # Yes
#  708 -> 0.3325 =>  0 =>  1 # No
#  709 -> 0.4812 =>  0 =>  1 # No
#  710 -> 0.4812 =>  0 =>  0 # Yes
#  711 -> 0.3326 =>  0 =>  0 # Yes
#  712 -> 0.3323 =>  0 =>  1 # No
#  713 -> 0.4812 =>  0 =>  0 # Yes
#  714 -> 0.3326 =>  0 =>  0 # Yes
#  715 -> 0.7527 =>  1 =>  1 # Yes
#  716 -> 0.7527 =>  1 =>  1 # Yes
#  717 -> 0.0012 =>  0 =>  0 # Yes
#  718 -> 0.0012 =>  0 =>  0 # Yes
#  719 -> 0.3257 =>  0 =>  1 # No
#  720 -> 0.3326 =>  0 =>  0 # Yes
#  721 -> 0.0013 =>  0 =>  0 # Yes
#  722 -> 0.7527 =>  1 =>  1 # Yes
#  723 -> 0.3320 =>  0 =>  0 # Yes
#  724 -> 0.3326 =>  0 =>  0 # Yes
#  725 -> 0.3324 =>  0 =>  0 # Yes
#  726 -> 0.4769 =>  0 =>  0 # Yes
#  727 -> 0.3326 =>  0 =>  0 # Yes
#  728 -> 0.3326 =>  0 =>  0 # Yes
#  729 -> 0.3326 =>  0 =>  0 # Yes
#  730 -> 0.3303 =>  0 =>  1 # No
#  731 -> 0.3326 =>  0 =>  1 # No
#  732 -> 0.7514 =>  1 =>  1 # Yes
#  733 -> 0.0045 =>  0 =>  0 # Yes
#  734 -> 0.3326 =>  0 =>  0 # Yes
#  735 -> 0.3309 =>  0 =>  0 # Yes
#  736 -> 0.3297 =>  0 =>  0 # Yes
#  737 -> 0.0017 =>  0 =>  0 # Yes
#  738 -> 0.4812 =>  0 =>  0 # Yes
#  739 -> 0.3326 =>  0 =>  1 # No
#  740 -> 0.7512 =>  1 =>  1 # Yes
#  741 -> 0.7527 =>  1 =>  0 # No
#  742 -> 0.0012 =>  0 =>  0 # Yes
#  743 -> 0.3326 =>  0 =>  1 # No
#  744 -> 0.7527 =>  1 =>  0 # No
#  745 -> 0.0065 =>  0 =>  0 # Yes
#  746 -> 0.3326 =>  0 =>  1 # No
#  747 -> 0.0017 =>  0 =>  0 # Yes
#  748 -> 0.7527 =>  1 =>  1 # Yes
#  749 -> 0.9442 =>  1 =>  1 # Yes
#  750 -> 0.3326 =>  0 =>  1 # No
#  751 -> 0.3316 =>  0 =>  0 # Yes
#  752 -> 0.3326 =>  0 =>  0 # Yes
#  753 -> 0.4812 =>  0 =>  1 # No
#  754 -> 0.3326 =>  0 =>  1 # No
#  755 -> 0.3297 =>  0 =>  1 # No
#  756 -> 0.3326 =>  0 =>  0 # Yes
#  757 -> 0.3326 =>  0 =>  1 # No
#  758 -> 0.3326 =>  0 =>  0 # Yes
#  759 -> 0.3324 =>  0 =>  1 # No
#  760 -> 0.3323 =>  0 =>  0 # Yes
#  761 -> 0.3326 =>  0 =>  1 # No
#  762 -> 0.3325 =>  0 =>  0 # Yes
#  763 -> 0.0012 =>  0 =>  0 # Yes
#  764 -> 0.3326 =>  0 =>  0 # Yes
#  765 -> 0.0013 =>  0 =>  0 # Yes
#  766 -> 0.2960 =>  0 =>  1 # No
#  767 -> 0.3326 =>  0 =>  0 # Yes

# %% [markdown]
# ## Done

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
# Out:
# Done! 2019-10-19 20:38:03.822029
