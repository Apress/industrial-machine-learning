# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# ## Chapter-011-24-Solve-Math-01

# %%
import sympy
sympy.init_printing()

# %%
from IPython.display import Image
Image(filename='../../data/BlockAlgebra01.png')

# %%
(w, a, b, c, 
 d, e, f, z, 
 P_21, P_22, 
 K, P_12, P_11) = sympy.symbols("""w, a, b, c, 
                                   d, e, f, z,
                                   P_21, P_22, 
                                   K, P_12, P_11""", commutative=False
                               )

# %%
eqs = [a - P_21*w,
       b - (a + d),
       c - K*b,
       d - P_22*c,
       e - P_12*c,
       f - P_11*w,
       z - (e + f)]

# %%
print(eqs)
# Out:
# [-P_21*w + a, b - (a + d), -K*b + c, -P_22*c + d, -P_12*c + e, -P_11*w + f, z - (e + f)]

# %%
# first we identify which variable can be eliminated by solving each equation
order = [a, b, c, d, e, f, z]
# This will store the solutions
solution = {}
for var, eq in zip(order, eqs):
    # We solve each equation for the new unknown given all the other solutions
    sol = sympy.solve(eq.subs(solution), var)[0]
    # and add that solution to the list of knowns
    solution[var] = sol
    
print('z=', solution[z].collect(w))
# Out:
# z= w*(P_11 + P_12*K*P_21 + P_12*K*(1 - K*P_22)**(-1)*P_22*K*P_21)

# %%
from IPython.display import Image
Image(filename='../../data/BlockAlgebra02.png')

# %% [markdown]
# You can perform this calculation manually as follows:

# %%
from IPython.display import Image
Image(filename='../../data/BlockAlgebra03.png')

# %% [markdown]
# ## Done

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
# Out:
# Done! 2019-04-28 16:39:29.635116
