# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# ## Chapter-008-009-Features-01

# %%
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest

iris = load_iris()

X, y = iris.data, iris.target

# This dataset is way too high-dimensional. Better do PCA:
pca = PCA(n_components=2)

# Maybe some original features where good, too?
selection = SelectKBest(k=1)

# Build estimator from PCA and Univariate selection:

combined_features = FeatureUnion([("pca", pca), ("univ_select", selection)])

# Use combined features to transform dataset:
X_features = combined_features.fit(X, y).transform(X)
print("Combined space has", X_features.shape[1], "features")

svm = SVC(kernel="linear")

# Do grid search over k, n_components and C:

pipeline = Pipeline([("features", combined_features), ("svm", svm)])

param_grid = dict(features__pca__n_components=[1, 2, 3],
                  features__univ_select__k=[1, 2],
                  svm__C=[0.1, 1, 10])

grid_search = GridSearchCV(pipeline, param_grid=param_grid, cv=5, verbose=10)
grid_search.fit(X, y)
print(grid_search.best_estimator_)
# Out:
# Combined space has 3 features
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1, score=0.8666666666666667, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1, score=0.9333333333333333, total=   0.1s
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=1, score=0.9, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=1
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.4s remaining:    0.0s
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=1, score=0.8666666666666667, total=   0.1s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=1
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.6s remaining:    0.0s
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=1, score=0.8333333333333334, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2, score=0.9333333333333333, total=   0.3s
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=1, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=1, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=1, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=1, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1, score=0.8666666666666667, total=   0.1s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=1, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=1, score=0.9666666666666667, total=   0.1s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=1, score=0.9666666666666667, total=   0.1s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=1, score=0.9, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2, score=0.9666666666666667, total=   0.1s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=2, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=2, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=2, score=0.9666666666666667, total=   0.1s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=2, score=1.0, total=   0.1s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=2, score=0.9, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=2, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=2, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1, score=1.0, total=   0.1s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=1, score=1.0, total=   0.1s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=1, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=1, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=1, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=1, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=1
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=1, score=1.0, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2, score=0.9333333333333333, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=0.1, features__pca__n_components=3, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=1, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=1, features__pca__n_components=3, features__univ_select__k=2, score=1.0, total=   0.1s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=2, score=1.0, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=2, score=0.9, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=2, score=0.9666666666666667, total=   0.0s
# [CV] svm__C=10, features__pca__n_components=3, features__univ_select__k=2
# [CV]  svm__C=10, features__pca__n_components=3, features__univ_select__k=2, score=1.0, total=   0.0s
# Pipeline(memory=None,
#      steps=[('features', FeatureUnion(n_jobs=1,
#        transformer_list=[('pca', PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)), ('univ_select', SelectKBest(k=1, score_func=<function f_classif at 0x7f726c2d7d08>))],
#        transformer...,
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:    5.0s finished

# %% [markdown]
# ## Done

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
