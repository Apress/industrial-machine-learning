# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# # Chapter 004 Example 006B

# %% [markdown]
# ## Part A - Load libraries

# %%
from sklearn import linear_model
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Part B - Load Data

# %%
fileName = '../../Data/Roses01.csv'
fileFullName = os.path.abspath(fileName)
print(fileFullName)
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrial Machine Learning\book\GitHub\Upload\industrial-machine-learning\Data\Roses01.csv

# %%
rosesdf= pd.read_csv(fileFullName,header=0)
print(rosesdf.shape)
print(rosesdf.columns)
# Out:
# (150, 6)
# Index(['F01', 'F02', 'F03', 'F04', 'T', 'T2'], dtype='object')

# %% [markdown]
# ## Part C - select first two features.

# %%
X = np.array(rosesdf[['F02', 'F03']]) 
Y = np.array(rosesdf['T'])

# %% [markdown]
# ## Part D - Create Logistic Regression Model

# %%
logreg = linear_model.LogisticRegression(C=1e6, solver='lbfgs', multi_class='ovr', n_jobs=4,verbose=True, max_iter=1968, dual=False, class_weight='balanced', warm_start=False)

# %% [markdown]
# ## Part E - Activate the Neighbours Classifier Model and fit the data.

# %%
logreg.fit(X, Y)
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    3.1s finished
# LogisticRegression(C=1000000.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=1968, multi_class='ovr', n_jobs=4, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=True,
#                    warm_start=False)

# %% [markdown]
# ## Part F - Plot the decision boundary.
# You will assign a color to each point in the mesh [x_min, x_max]x[y_min, y_max].

# %%
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])

# %% [markdown]
# ## Part G - Put the result into a color plot with the the training points

# %%
Z = Z.reshape(xx.shape)
fig = plt.figure(1, figsize=(12, 9))
plt.title('Roses - Features F02 and F03')
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors='k', cmap=plt.cm.Paired, marker='D', s=120)
plt.xlabel('Feature 2')
plt.ylabel('Fearure 3')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())

plt.show()

# %%
imagepath = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 04'])
print(imagepath)
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrial Machine Learning\book\GitHub\Upload\industrial-machine-learning\Results\Chapter 04

# %%
if not os.path.exists(imagepath):
    os.makedirs(imagepath)

# %%
imagename = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 04','Chapter-004-Example-006B-01.jpg'])
fig.savefig(imagename, bbox_inches='tight')

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
# Out:
# Done! 2019-10-19 17:21:01.204455
