# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# ## Chapter-010-17-Konigsberg-01

# %%
import matplotlib
import numpy as np
matplotlib.use('TkAgg')
# %matplotlib inline

import networkx as nx
import matplotlib.pyplot as plt

# %%
nodes = [0, 3]
edges = [
    (0, 1, {'key': 'Grüne Brücke', 'color': 'blue', 'width': 5}),
    (0, 1, {'key': 'Köttelbrücke', 'color': 'red', 'width': 2}),
    (1, 2, {'key': 'Krämerbrücke', 'color': 'blue', 'width': 5}),
    (1, 2, {'key': 'Schmiedebrücke', 'color': 'red', 'width': 2}),
    (2, 3, {'key': 'Holzbrücke', 'color': 'blue', 'width': 5}),
    (3, 1, {'key': 'Dombrücke', 'color': 'blue', 'width': 5}),
    (3, 0, {'key': 'Hohe Brücke', 'color': 'blue', 'width': 5})
]

# %%
# Create the graph
graph = nx.MultiGraph()
graph.add_nodes_from(nodes)
r=graph.add_edges_from(edges)

# %%
for i, j, label in graph.edges(data='key'):
    print(i, j, label)
# Out:
# 0 1 Grüne Brücke
# 0 1 Köttelbrücke
# 0 3 Hohe Brücke
# 3 2 Holzbrücke
# 3 1 Dombrücke
# 1 2 Krämerbrücke
# 1 2 Schmiedebrücke

# %%
labels = {}
for i, j, label in graph.edges(data='key'):
    if (i, j) not in labels:
        labels[(i, j)] = label
    else:
        labels[(i, j)] += '\n' + label

# %%
colors = [x for _, _, x in graph.edges(data='color')]

# %%
widths = [x for _, _, x in graph.edges(data='width')]

# %%
pos = nx.spring_layout(graph,scale=2.5,iterations=250)

# %%
# Plot the graph
# %matplotlib inline
fig=plt.figure(figsize=(10,10))
nx.draw_networkx(graph, pos, edge_color=colors, with_labels=True, width=widths, alpha=1.0)
nx.draw_networkx_edge_labels(graph, pos, edge_labels=labels)
plt.axis('off')
plt.show()
# Out:
# C:\Users\AndreVermeulen\.conda\envs\andre\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\AndreVermeulen\.conda\envs\andre\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \

# %% [markdown]
# ## Done

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
# Out:
# Done! 2019-10-19 22:28:50.608610
