# %% [markdown]
# # Chapter 001 Test Eco-system

# %%
#!pip install -U pip --user

# %%
import os
curDir = os.getcwd()
print('Your current directory is:', curDir)
# Out:
# Your current directory is: C:\Users\AndreVermeulen\Documents\My Book\apress\Industrial Machine Learning\book\GitHub\Upload\industrial-machine-learning\Code\Chapter 001

# %%
try:
    import numpy
    print('Library: numpy working')
except:    
    print('Library: numpy not working')
    #!pip install -U numpy --user
# Out:
# Library: numpy working

# %%
try:
    import matplotlib
    print('Library: matplotlib working')
except:    
    print('Library: matplotlib not working')
    #!pip install -U matplotlib --user
# Out:
# Library: matplotlib working

# %%
try:
    import scipy
    print('Library: scipy working')
except:    
    print('Library: scipy not working')
    #!pip install -U scipy --user
# Out:
# Library: scipy working

# %%
from scipy import special, optimize, linspace
import matplotlib.pyplot as plt
# %matplotlib inline

f = lambda x: -special.jv(3, x)
sol = optimize.minimize(f, 1.0)
x = linspace(0, 50, 500)
fig = plt.figure(figsize=(15, 5))
plt.plot(x, special.jv(3, x), '-', sol.x, -sol.fun, 'o')
plt.show()

# %%
try:
    import sklearn
    print('Library: scikit-learn working')
except:    
    print('Library: scikit-learn not working')
    #!pip install -U scikit-learn --user
# Out:
# Library: scikit-learn working

# %%
try:
    import pandas
    print('Library: pandas working')
except:    
    print('Library: pandas not working')
    #!pip install -U pandas --user
# Out:
# Library: pandas working

# %%
import pandas as pd
from sklearn.datasets import load_wine
dataraw = load_wine()
data = pd.DataFrame(dataraw['data'])
print(data.shape)
# Out:
# (178, 13)

# %%
try:
    import PyYAML
    print('Library: PyYAML working')
except:    
    print('Library: PyYAML not working')
    #!pip install -U PyYAML --user
# Out:
# Library: PyYAML not working

# %%
try:
    import networkx
    print('Library: networkx working')
except:    
    print('Library: networkx not working')
    #!pip install -U networkx --user
# Out:
# Library: networkx working

# %%
import networkx as nx
G=nx.cubical_graph()
print(G.number_of_nodes())
print(G.degree())
# Out:
# 8
# [(0, 3), (1, 3), (2, 3), (3, 3), (4, 3), (5, 3), (6, 3), (7, 3)]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))

pos=nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos,
                       nodelist=[0,1,2,3],
                       node_color='r',
                       node_size=500,
                       alpha=0.8)
nx.draw_networkx_nodes(G,pos,
                       nodelist=[4,5,6,7],
                       node_color='b',
                       node_size=500,
                       alpha=0.5)
nx.draw_networkx_edges(G,pos,width=3.0,alpha=0.5)
nx.draw_networkx_edges(G,pos,
                       edgelist=[(0,1),(1,2),(2,3),(3,0)],
                       width=5,alpha=0.5,edge_color='r')
nx.draw_networkx_edges(G,pos,
                       edgelist=[(4,5),(5,6),(6,7),(7,4)],
                       width=5,alpha=0.5,edge_color='b')
plt.axis('off')
plt.show()

# %%
print('Your system is ready!')
# Out:
# Your system is ready!
