# %% [markdown]
# ## Apress - Industrialized Machine Learning Examples
#
# Andreas Francois Vermeulen
# 2019
#
# ### This is an example add-on to a book and needs to be accepted as part of that copyright.

# %% [markdown]
# k-means clustering is a method of vector quantization, originally from signal processing, that is popular for cluster analysis in data mining.
#
# k-means clustering aims to partition n observations into k clusters in which each observation belongs to the cluster with the nearest mean, serving as a prototype of the cluster.
#
# This results in a partitioning of the data space into Voronoi cells.

# %%
N=int(20)
M=int(100)

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
seednum=0
np.random.seed(seednum)

# %%
from sklearn.cluster import KMeans

# %%
K1=[]
for i in range(-M, M):
    K1 = K1+[[i,i]]
    K1 = K1+[[0,i]]
    K1 = K1+[[i,0]]
    K1 = K1+[[-i,i]]
#print(K1)

# %%
X = np.array(K1)

# %%
K2=[]
for i in range(-M, M):
    for j in range(-M, M):
        K2 = K2+[[i,j]]
#print(K2)

# %%
T = np.array(K2)

# %% [markdown]
# ## KMeans One

# %%
km1 = KMeans(n_clusters=N, 
                random_state=seednum, 
                init='k-means++',
                algorithm='auto',
                tol=1e-06,
                max_iter=1000,
                n_jobs=-1,
                n_init=100,
                verbose=True
               )
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
km1.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#        n_clusters=20, n_init=100, n_jobs=-1, precompute_distances='auto',
#        random_state=0, tol=1e-06, verbose=True)

# %%
print(km1.get_params(deep=True))
# Out:
# {'algorithm': 'auto', 'copy_x': True, 'init': 'k-means++', 'max_iter': 1000, 'n_clusters': 20, 'n_init': 100, 'n_jobs': -1, 'precompute_distances': 'auto', 'random_state': 0, 'tol': 1e-06, 'verbose': True}

# %%
print(km1.n_iter_)
# Out:
# 10

# %%
print(km1.labels_)
# Out:
# [ 5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0
#   5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0
#   5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0
#   5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0
#   5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  0  5 11  3  8
#  13 11  3  8 13 11  3  8 13 11  3  8 13 11  3  8 13 11  3  8 13 11  3  8
#  13 11  3  8 13 11  3  8 13 11  3  8 13 11 19  8 13  1 19  8 13  1 19  8
#  13  1 19  8 13  1 19  8 13  1 19  8 13  1 19  8 13  1 19  8 13  1 19  8
#  13  1 19  8 13  1 19  8 13  1 19  8 13  1 19  8 13  1 19  8 13  1 19  8
#  13  1 19  8 13  1 19  8 13  1 19  8 13  1 19  8 16  1 19  8 16  1 19 18
#  16  1 19 18 16  1 19 18 16  1 19 18 16  1 19 18 16  1 19 18 16  1 19 18
#  16  1 19 18 16  1 19 18 16  1 19 18 16  1 19 18 16  1 19 18 16  1 19 18
#  16  1 19 18 16  1 19 18 16  1 19 18 16  1 19 18 16  1 19 18 16  1 19 18
#  16  1 19 18 16  1 19 18 16  4  4 18 16  4  4 18 16  4  4 18 16  4  4 18
#  16  4  4 18 16  4  4 18  4  4  4 18  4  4  4  4  4  4  4  4  4  4  4  4
#   4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4
#   4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4
#   4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4
#   4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4  4 15  4  4  4
#  15  4  4 10 15  4  4 10 15 15  4 10 15 15  4 10 15 15  4 10 15 15  4 10
#  15 15  4 10 15 15 14 10 15 15 14 10 15 15 14 10 15 15 14 10 15 15 14 10
#  15 15 14 10 15 15 14 10 15 15 14 10 15 15 14 10 15 15 14 10 15 15 14 10
#  15 15 14 10  6 15 14 10  6 15 14 10  6 15 14 10  6 15 14 10  6 15 14 10
#   6 15 14 10  6 15 14 10  6 15 14 10  6 15 14 10  6 15 14  7  6 15 14  7
#   6 15 14  7  6 15 14  7  6 15 14  7  6 15 14  7  6 15 14  7  6 15 14  7
#   6 15 14  7  6 15 14  7  6 15 14  7  6  2 14  7  6  2 14  7  6  2 14  7
#   6  2 14  7  6  2 14  7  6  2 14  7  6  2 14  7  6  2 14  7  6  2  9  7
#   6  2  9  7  6  2  9  7  6  2  9  7  6  2  9  7  6  2  9  7 12  2  9  7
#  12  2  9  7 12  2  9  7 12  2  9  7 12  2  9 17 12  2  9 17 12  2  9 17
#  12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17
#  12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17
#  12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17
#  12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17 12  2  9 17
#  12  2  9 17 12  2  9 17]

# %%
z1 = km1.predict(X)

# %%
p1 = km1.predict(T)

# %% [markdown]
# ## KMeans Two

# %%
km2 = KMeans(n_clusters=N, 
                random_state=seednum, 
                init='random',
                algorithm='auto',
                tol=1e-06,
                max_iter=1000,
                n_jobs=-1,
                n_init=100,
                verbose=True
               )

# %%
km2.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=1000,
#        n_clusters=20, n_init=100, n_jobs=-1, precompute_distances='auto',
#        random_state=0, tol=1e-06, verbose=True)

# %%
print(km2.get_params(deep=True))
# Out:
# {'algorithm': 'auto', 'copy_x': True, 'init': 'random', 'max_iter': 1000, 'n_clusters': 20, 'n_init': 100, 'n_jobs': -1, 'precompute_distances': 'auto', 'random_state': 0, 'tol': 1e-06, 'verbose': True}

# %%
print(km2.n_iter_)
# Out:
# 16

# %%
print(km2.labels_)
# Out:
# [11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7
#  11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7
#  11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7
#  11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7 11 18 13  7
#  11 18 13  7 11 18 13  7 11 18 13 15 11 18 13 15 11 18 13 15 11 18 13 15
#   3 18 13 15  3 18 13 15  3 18 13 15  3 18 13 15  3 18 19 15  3 18 19 15
#   3 18 19 15  3 18 19 15  3 18 19 15  3 18 19 15  3  8 19 15  3  8 19 15
#   3  8 19 15  3  8 19 15  3  8 19 15  3  8 19 15  3  8 19 15  3  8 19 15
#   3  8 19 15  3  8 19 15  3  8 19 15  3  8 19 15  3  8 19 15  3  8 19 15
#   3  8 19 14  3  8 19 14  3  8 19 14  3  8 19 14  0  8 19 14  0  8 19 14
#   0  8 19 14  0  8 19 14  0  8 19 14  0  8 19 14  0  8 19 14  0  8 19 14
#   0  8 19 14  0  8 12 14  0  8 12 14  0  8 12 14  0  8 12 14  0  8 12 14
#   0  8 12 14  0  8 12 14  0  8 12 14  0  8 12 14  0  8 12 14  0  8 12 14
#   0  8 12 14  0 10 12 14  0 10 12 14  0 10 12 14  0 10 12 14  0 10 12 10
#   0 10 12 10  0 10 12 10 10 10 12 10 10 10 12 10 10 10 12 10 10 10 12 10
#  10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10
#  10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10
#  10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 10
#  10 10 10 12 10 10 10 12 10 10 10 12 10 10 10 12 17 10 10 12 17 10 10 12
#  17 17 10 12 17 17 10 12 17 17 10 12 17 17 10 12 17 17 10 12 17 17 10 12
#  17 17 10 12 17 17 10 12 17 17  5 12 17 17  5 12 17 17  5 12 17 17  5 12
#  17 17  5 12 17 17  5 12 17 17  5 12 17 17  5 12  6 17  5 12  6 17  5  2
#   6 17  5  2  6 17  5  2  6 17  5  2  6 17  5  2  6 17  5  2  6 17  5  2
#   6 17  5  2  6 17  5  2  6 17  5  2  6 17  5  2  6 17  5  2  6 17  5  2
#   6 17  5  2  6 17  5  2  6 17  5  2  6 17  5  2  6 17  5  2  6 17  5  2
#   6 17  5  2  6 17  5  2  6  4  5  2  6  4  5  2  6  4  5  2  6  4  5  2
#   6  4  5  2  6  4  5  2  6  4  5  2  6  4  5  2  6  4  1  2  6  4  1  2
#   6  4  1  2  6  4  1  2  9  4  1  2  9  4  1 16  9  4  1 16  9  4  1 16
#   9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16
#   9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16
#   9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16
#   9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16
#   9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16  9  4  1 16
#   9  4  1 16  9  4  1 16]

# %%
z2 = km2.predict(X)

# %%
p2 = km2.predict(T)

# %% [markdown]
# ## Plot Results - KMeans One

# %%
#for i in range(X.shape[0]):
#    print(X[i], z1[i])

# %%
print(X.shape, z1.shape)
# Out:
# (800, 2) (800,)

# %%
x1, y1=zip(*X)
c1=z1[:]
#print(x1,y1,c1)

# %%
g1=pd.DataFrame(c1)
g1.columns=['Cluster']
gc1=g1['Cluster'].value_counts()
gcs1=gc1.sum()

for i in range(gc1.shape[0]):
    print('Cluster %3d : %4d (%7.3f %%)' % (i+1,gc1[i],((gc1[i]/gcs1)*100)))
print('----------------------')
print('Cluster     : %4d' % (gc1.sum()))
# Out:
# Cluster   1 :   29 (  3.625 %)
# Cluster   2 :   40 (  5.000 %)
# Cluster   3 :   47 (  5.875 %)
# Cluster   4 :   40 (  5.000 %)
# Cluster   5 :  131 ( 16.375 %)
# Cluster   6 :   30 (  3.750 %)
# Cluster   7 :   34 (  4.250 %)
# Cluster   8 :   29 (  3.625 %)
# Cluster   9 :   30 (  3.750 %)
# Cluster  10 :   39 (  4.875 %)
# Cluster  11 :   28 (  3.500 %)
# Cluster  12 :   40 (  5.000 %)
# Cluster  13 :   33 (  4.125 %)
# Cluster  14 :   28 (  3.500 %)
# Cluster  15 :   40 (  5.000 %)
# Cluster  16 :   57 (  7.125 %)
# Cluster  17 :   28 (  3.500 %)
# Cluster  18 :   29 (  3.625 %)
# Cluster  19 :   28 (  3.500 %)
# Cluster  20 :   40 (  5.000 %)
# ----------------------
# Cluster     :  800

# %%
fig1=plt.figure(figsize=(12, 12))
titlename = 'KMeans on %03d nodes with %03d clusters (k-means++)' % (M,N)
plt.title(titlename)
plt.xlabel('X-Grid')
plt.ylabel('Y-Grid')
plt.scatter(x1, y1,marker='p',c=c1, s=100)
plt.show()

# %%
#for i in range(T.shape[0]):
#    print(T[i], p1[i])

# %%
x2, y2= zip(*T)
c2=p1[:]

# %%
c2.shape[0]
# Out:
# 40000

# %%
g2=pd.DataFrame(c2)
g2.columns=['Cluster']
gc2=g2['Cluster'].value_counts()
gcs2=gc2.sum()

for i in range(gc2.shape[0]):
    print('Cluster %3d : %4d (%7.3f %%)' % (i+1,gc2[i],((gc2[i]/gcs2)*100)))
print('----------------------')
print('Cluster     : %4d' % (gcs2))
# Out:
# Cluster   1 : 1653 (  4.133 %)
# Cluster   2 : 1342 (  3.355 %)
# Cluster   3 : 2929 (  7.322 %)
# Cluster   4 : 2667 (  6.667 %)
# Cluster   5 : 1238 (  3.095 %)
# Cluster   6 : 1770 (  4.425 %)
# Cluster   7 : 2657 (  6.643 %)
# Cluster   8 : 2704 (  6.760 %)
# Cluster   9 : 2759 (  6.897 %)
# Cluster  10 : 2602 (  6.505 %)
# Cluster  11 : 1449 (  3.623 %)
# Cluster  12 : 2668 (  6.670 %)
# Cluster  13 : 2153 (  5.382 %)
# Cluster  14 : 2668 (  6.670 %)
# Cluster  15 : 1569 (  3.923 %)
# Cluster  16 : 1528 (  3.820 %)
# Cluster  17 : 1304 (  3.260 %)
# Cluster  18 : 1711 (  4.277 %)
# Cluster  19 : 1286 (  3.215 %)
# Cluster  20 : 1343 (  3.357 %)
# ----------------------
# Cluster     : 40000

# %%
fig2=plt.figure(figsize=(12, 12))
titlename = 'KMeans Voronoi cells for %03d nodes with %03d clusters (k-means++)' % (M,N)
plt.title(titlename)
plt.xlabel('X-Grid')
plt.ylabel('Y-Grid')
plt.scatter(x2, y2,marker="o",c=c2, s=100)
plt.show()

# %% [markdown]
# ## Plot Results - KMeans Two

# %%
#for i in range(X.shape[0]):
#    print(X[i], z2[i])

# %%
print(X.shape, z2.shape)
# Out:
# (800, 2) (800,)

# %%
x1, y1=zip(*X)
c1=z2[:]
#print(x1,y1,c1)

# %%
g3=pd.DataFrame(c1)
g3.columns=['Cluster']
gc3=g3['Cluster'].value_counts()
gcs3=gc3.sum()

for i in range(gc3.shape[0]):
    print('Cluster %3d : %4d (%7.3f %%)' % (i+1,gc3[i],((gc3[i]/gcs3)*100)))
print('----------------------')
print('Cluster     : %4d' % (gcs3))
# Out:
# Cluster   1 :   28 (  3.500 %)
# Cluster   2 :   40 (  5.000 %)
# Cluster   3 :   34 (  4.250 %)
# Cluster   4 :   29 (  3.625 %)
# Cluster   5 :   48 (  6.000 %)
# Cluster   6 :   38 (  4.750 %)
# Cluster   7 :   35 (  4.375 %)
# Cluster   8 :   27 (  3.375 %)
# Cluster   9 :   39 (  4.875 %)
# Cluster  10 :   35 (  4.375 %)
# Cluster  11 :  118 ( 14.750 %)
# Cluster  12 :   29 (  3.625 %)
# Cluster  13 :   46 (  5.750 %)
# Cluster  14 :   34 (  4.250 %)
# Cluster  15 :   29 (  3.625 %)
# Cluster  16 :   27 (  3.375 %)
# Cluster  17 :   35 (  4.375 %)
# Cluster  18 :   56 (  7.000 %)
# Cluster  19 :   40 (  5.000 %)
# Cluster  20 :   33 (  4.125 %)
# ----------------------
# Cluster     :  800

# %%
fig3=plt.figure(figsize=(12, 12))
titlename = 'KMeans on %03d nodes with %03d clusters (random)' % (M,N)
plt.title(titlename)
plt.xlabel('X-Grid')
plt.ylabel('Y-Grid')
plt.scatter(x1, y1,marker='p',c=c1, s=100)
plt.show()

# %%
#for i in range(T.shape[0]):
#    print(T[i], p2[i])

# %%
x2, y2= zip(*T)
c2=p2[:]

# %%
c2.shape[0]
# Out:
# 40000

# %%
g4=pd.DataFrame(c2)
g4.columns=['Cluster']
gc4=g4['Cluster'].value_counts()
gcs4=gc4.sum()

for i in range(gc4.shape[0]):
    print('Cluster %3d : %4d (%7.3f %%)' % (i+1,gc4[i],((gc4[i]/gcs4)*100)))
print('----------------------')
print('Cluster     : %4d' % (gcs4))
# Out:
# Cluster   1 : 1356 (  3.390 %)
# Cluster   2 : 2663 (  6.657 %)
# Cluster   3 : 2649 (  6.623 %)
# Cluster   4 : 2679 (  6.698 %)
# Cluster   5 : 2996 (  7.490 %)
# Cluster   6 : 1478 (  3.695 %)
# Cluster   7 : 2556 (  6.390 %)
# Cluster   8 : 1378 (  3.445 %)
# Cluster   9 : 1329 (  3.322 %)
# Cluster  10 : 2364 (  5.910 %)
# Cluster  11 : 1077 (  2.692 %)
# Cluster  12 : 1711 (  4.277 %)
# Cluster  13 : 1123 (  2.808 %)
# Cluster  14 : 2400 (  6.000 %)
# Cluster  15 : 1514 (  3.785 %)
# Cluster  16 : 2701 (  6.753 %)
# Cluster  17 : 2360 (  5.900 %)
# Cluster  18 : 1588 (  3.970 %)
# Cluster  19 : 2672 (  6.680 %)
# Cluster  20 : 1406 (  3.515 %)
# ----------------------
# Cluster     : 40000

# %%
fig4=plt.figure(figsize=(12, 12))
titlename = 'KMeans Voronoi cells for %03d nodes with %03d clusters (random)' % (M,N)
plt.title(titlename)
plt.xlabel('X-Grid')
plt.ylabel('Y-Grid')
plt.scatter(x2, y2,marker="o",c=c2, s=100)
plt.show()

# %%
for i in range(gc2.shape[0]):
    result='Cluster %3d : (k-means++) %4d (%7.3f %%) vs (random) %4d (%7.3f %%) (Net: %5d)' \
    % (i+1, gc2[i], ((gc2[i]/gcs2)*100), gc4[i], ((gc4[i]/gcs4)*100), (gc2[i]-gc4[i]))
    
    print(result)
print('----------------------')
print('Cluster     : %4d' % (gcs2))
# Out:
# Cluster   1 : (k-means++) 1653 (  4.133 %) vs (random) 1356 (  3.390 %) (Net:   297)
# Cluster   2 : (k-means++) 1342 (  3.355 %) vs (random) 2663 (  6.657 %) (Net: -1321)
# Cluster   3 : (k-means++) 2929 (  7.322 %) vs (random) 2649 (  6.623 %) (Net:   280)
# Cluster   4 : (k-means++) 2667 (  6.667 %) vs (random) 2679 (  6.698 %) (Net:   -12)
# Cluster   5 : (k-means++) 1238 (  3.095 %) vs (random) 2996 (  7.490 %) (Net: -1758)
# Cluster   6 : (k-means++) 1770 (  4.425 %) vs (random) 1478 (  3.695 %) (Net:   292)
# Cluster   7 : (k-means++) 2657 (  6.643 %) vs (random) 2556 (  6.390 %) (Net:   101)
# Cluster   8 : (k-means++) 2704 (  6.760 %) vs (random) 1378 (  3.445 %) (Net:  1326)
# Cluster   9 : (k-means++) 2759 (  6.897 %) vs (random) 1329 (  3.322 %) (Net:  1430)
# Cluster  10 : (k-means++) 2602 (  6.505 %) vs (random) 2364 (  5.910 %) (Net:   238)
# Cluster  11 : (k-means++) 1449 (  3.623 %) vs (random) 1077 (  2.692 %) (Net:   372)
# Cluster  12 : (k-means++) 2668 (  6.670 %) vs (random) 1711 (  4.277 %) (Net:   957)
# Cluster  13 : (k-means++) 2153 (  5.382 %) vs (random) 1123 (  2.808 %) (Net:  1030)
# Cluster  14 : (k-means++) 2668 (  6.670 %) vs (random) 2400 (  6.000 %) (Net:   268)
# Cluster  15 : (k-means++) 1569 (  3.923 %) vs (random) 1514 (  3.785 %) (Net:    55)
# Cluster  16 : (k-means++) 1528 (  3.820 %) vs (random) 2701 (  6.753 %) (Net: -1173)
# Cluster  17 : (k-means++) 1304 (  3.260 %) vs (random) 2360 (  5.900 %) (Net: -1056)
# Cluster  18 : (k-means++) 1711 (  4.277 %) vs (random) 1588 (  3.970 %) (Net:   123)
# Cluster  19 : (k-means++) 1286 (  3.215 %) vs (random) 2672 (  6.680 %) (Net: -1386)
# Cluster  20 : (k-means++) 1343 (  3.357 %) vs (random) 1406 (  3.515 %) (Net:   -63)
# ----------------------
# Cluster     : 40000

# %% [markdown]
# ## Save Results - KMeans

# %%
imagepath = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 06'])
print(imagepath)

if not os.path.exists(imagepath):
    os.makedirs(imagepath)
    
figname='Chapter-006-Example-002-%03d-01.jpg' % (N)    
imagename = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 06',figname])
fig1.savefig(imagename, bbox_inches='tight')

figname='Chapter-006-Example-002-%03d-02.jpg' % (N)
imagename = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 06',figname])
fig2.savefig(imagename, bbox_inches='tight') 
    
figname='Chapter-006-Example-002-%03d-03.jpg' % (N)    
imagename = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 06',figname])
fig3.savefig(imagename, bbox_inches='tight')

figname='Chapter-006-Example-002-%03d-04.jpg' % (N)
imagename = os.path.join(*[os.path.dirname(os.path.dirname(os.getcwd())),'Results','Chapter 06',figname])
fig4.savefig(imagename, bbox_inches='tight')
# Out:
# C:\Users\AndreVermeulen\Documents\My Book\apress\Industrial Machine Learning\book\GitHub\Upload\industrial-machine-learning\Results\Chapter 06

# %% [markdown]
# ## Done

# %%
import datetime
now = datetime.datetime.now()
print('Done!',str(now))
# Out:
# Done! 2019-10-19 19:50:43.748030
